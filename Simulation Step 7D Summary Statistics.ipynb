# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Prelude" data-toc-modified-id="Prelude-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Prelude</a></span></li><li><span><a href="#Utilities-(as-before)" data-toc-modified-id="Utilities-(as-before)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Utilities (as before)</a></span></li><li><span><a href="#Finding-Shortest-Path-(as-before)" data-toc-modified-id="Finding-Shortest-Path-(as-before)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Finding Shortest Path (as before)</a></span></li><li><span><a href="#Finding-Shortest-Delivery-Route-(as-before)" data-toc-modified-id="Finding-Shortest-Delivery-Route-(as-before)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Finding Shortest Delivery Route (as before)</a></span></li><li><span><a href="#Time-Handling" data-toc-modified-id="Time-Handling-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Time Handling</a></span></li><li><span><a href="#Class-Recorder" data-toc-modified-id="Class-Recorder-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Class Recorder</a></span></li><li><span><a href="#Class-Parcel" data-toc-modified-id="Class-Parcel-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Class Parcel</a></span></li><li><span><a href="#Class-Customer" data-toc-modified-id="Class-Customer-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Class Customer</a></span></li><li><span><a href="#Class-Driver" data-toc-modified-id="Class-Driver-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Class Driver</a></span></li><li><span><a href="#Class-Delivery-Centre" data-toc-modified-id="Class-Delivery-Centre-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Class Delivery Centre</a></span></li><li><span><a href="#Simulation" data-toc-modified-id="Simulation-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Simulation</a></span><ul class="toc-item"><li><span><a href="#Parameters-from-Specification" data-toc-modified-id="Parameters-from-Specification-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Parameters from Specification</a></span></li><li><span><a href="#Generate-Input-Data" data-toc-modified-id="Generate-Input-Data-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Generate Input Data</a></span></li><li><span><a href="#Simulation-Routine" data-toc-modified-id="Simulation-Routine-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Simulation Routine</a></span></li><li><span><a href="#Model-Verification" data-toc-modified-id="Model-Verification-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>Model Verification</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Prelude

# %%
import matplotlib.pyplot as plt
import pulp
import math
import random
import pandas as pd
import numpy as np
import time
import simpy

# %% [markdown]
# # Utilities (as before)

# %% [markdown]
# ## Points and Distances

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2))

# %% [markdown]
# ## PlotMap

# %%
def plotMap(G, T=[], P=[], W=None,
            style='r-o', lw=1, ms=3, 
            styleT='go', msT=5,
            styleP='b-o', lwP=3, msP=1,
            stylePT='go', msPT=7,
            styleW='bo', msW=9,
            text=None, grid=False):
    fig = plt.gcf()
    fig.set_size_inches(6, 6)
    V, E = G

    if not grid:
        plt.axis('off')
    plt.plot( [ p[0] for p in V ], [ p[1] for p in V ], 'ro', lw=lw, ms=ms)
    for (p, q) in E:
        plt.plot( [ p[0], q[0] ], [ p[1], q[1] ], 'r-o', lw=lw, ms=ms)
    for t in T:
        plt.plot( [ t[0] ], [ t[1] ], 
                  styleT, ms=msT)
    plt.plot( [ p[0] for p in P ],
              [ p[1] for p in P ], 
              styleP, lw=lwP, ms=msP)
    for p in P:
        if p in T:
            plt.plot( [ p[0] ], [ p[1] ], 
                      stylePT, ms=msPT)
    if W is not None:
        plt.plot( [ W[0] ], [ W[1] ], 
                      styleW, ms=msW)
    if text is not None:
        maxX = max([p[0] for p in V])
        plt.text(0.8*maxX, 0, text)
    if grid:
        plt.grid()
    plt.show()

# %% [markdown]
# ## Add Targets

# %%
def addTargets(M, T):
    V, E = M
    E = E.copy()
    V = V.copy()
    for t in T:
        minD = math.inf
        minE = None
        for e in E:
            P, Q = e
            distT = dist(P, t)+dist(t, Q)-dist(P, Q)
            if distT < minD:
                minD = distT
                minE = e
        P, Q = minE
        E.remove( (P, Q) )
        E.append( (P, t) )
        E.append( (t, Q) )
        V.append(t)
    return V, E

# %% [markdown]
# ## Generate Warehouse Location

# %%
def generateWarehouseLocation(M):
    V, _ = M
    W = random.sample(V, k=1)[0]
    return W

# %% [markdown]
# ## Time Handling

# %% [markdown]
# **Convention:** In this project we measure time in seconds. The simulation will start at 0:00. Time related methods will be added as they are needed.

# %% [markdown]
# `timestamp(t)` generates a timestamp string in the form `[dd] hh:mm:ss.d`

# %%
def timestamp(t):
    day = int(t)//(24*3600)
    t = t - day*24*3600
    hour = int(t)//3600
    t = t - hour*3600
    mins = int(t)//60
    t = t - mins*60
    secs = int(math.floor(t))
    t = int(math.floor((t - secs)*10))
    return f"[{day:2d}] {hour:02d}:{mins:02d}:{secs:02d}.{t:1d}"

# %%
timestamp(24*3600*3+17*3600+615.1)
# Out:
# '[ 3] 17:10:15.0'

# %%
def nextHour(env, hour):
    beginningOfDay = int(env.now//(24*3600))*24*3600
    timeOfDay = env.now-beginningOfDay
    if hour*3600 > timeOfDay:
        return hour*3600 - timeOfDay
    else:
        return hour*3600 + 24*3600 - timeOfDay

# %%
def day(now):
    return int(now//(24*3600))

# %% [markdown]
# ## Plotting Routines

# %%
import scipy.stats as stats

def histplot(data, title="", xlabel="",
             width=None, height=None):
    
    minx = min(data)
    maxx = max(data)
    μ = np.mean(data)
    σ = np.std(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 4)
    fig.set_figheight(height if height is not None else 2.5)
    ax = fig.gca()
        
    hist=plt.hist(data, density=True)
    plt.xlabel(xlabel)
    plt.ylabel('Density')
    plt.title(title)
        
    x = np.linspace(minx, maxx, 100)
    y = [ stats.norm(loc=μ, scale=σ).pdf(p) for p in x]
    ax.plot(x, y, lw=1, color='red')
    ax.axvline(x=μ, color='red')
    maxy = max(max(y), max(hist[0]))
    ax.text(maxx, maxy, 
            f'μ={μ:2.2f}\nσ={σ:2.2f}', 
            ha='right', va='top', 
            color='red', fontsize=12)
    ax.grid(True)
    plt.show()

# %%
def dailyPlot(data, 
              title="", ylabel="",
              width=None, height=None):
    
    days = len(data)
    
    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 6)
    fig.set_figheight(height if height is not None else 2)
    
    ax = fig.gca()
    diff = (max(data)-min(data))*0.1
    ymin = int(math.floor(min(data)-diff))
    ymax = int(math.ceil(max(data)+diff))
    ax.set_xlim(-1, days)
    ax.set_ylim(ymin, ymax)
    ax.grid(True)
    
    ms = 2 if len(data)>100 else 5
    lw = 0.5 if len(data)>100 else 1

    x = np.arange(0, len(data))
    y = np.array([ y for y in data ])
    b, m = np.polynomial.polynomial.polyfit(x, y, 1)
    
    plt.plot(x, y, 'bo-', linewidth=lw, markersize=ms)
    plt.plot(x, m*x+b, 'r-')
    
    plt.xlabel('Day')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Finding Shortest Path (as before)

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2))

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %%
def shortestPath(M, A, B):

    def h(p): 
        return pathLength(p)+dist(p[-1],B)
    
    # candidates C are pairs of the path so far and 
    # the heuristic function of that path, 
    # sorted by the heuristic function, as maintained by
    # insert function
    def insert(C, p):
        hp = h(p)
        c = (p, hp)
        for i in range(len(C)):
            if C[i][1]>hp:
                return C[:i]+[c]+C[i:]
        return C+[c]   
        
    V, E = M
    assert(A in V and B in V)    
    C = insert([], [A])

    while len(C)>0:
        # take the first candidate out of the list of candidates
        path, _ = C[0]
        C = C[1:]
        if path[-1]==B:
            return path
        else:
            for (x, y) in E:
                if path[-1]==x and y not in path:
                    C = insert(C, path+[y])
                elif path[-1]==y and x not in path:
                    C = insert(C, path+[x])
    return None

# %% [markdown]
# # Finding Shortest Delivery Route (as before)

# %% [markdown]
# ## Iterative Integer Programming

# %%
def createTables(M, T):

    def reverse(P):
        return [ P[-i] for i in range(1,len(P)+1) ]
    
    def index(x, L):
        for i in range(len(L)):
            if x==L[i]: 
                return i
        return None

    n = len(T)
    d = [ [ math.inf for t in T ] for t in T ]
    p = [ [ None for t in T ] for t in T ]
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [ T[i] ]
    for i in range(n):
        for j in range(n):
            if p[i][j] is None:
                s = shortestPath(M, T[i], T[j])
                d[i][j] = d[j][i] = pathLength(s)
                p[i][j] = s
                p[j][i] = reverse(s)
                for m in range(len(s)-1):
                    smi = index(s[m], T)
                    if smi is None:
                        continue
                    for l in range(m+1, len(s)):
                        sli = index(s[l], T)
                        if sli is None:
                            continue  
                        sub = s[m:l+1]
                        if p[smi][sli] is None:
                            p[smi][sli] = sub
                            p[sli][smi] = reverse(sub)
                            d[smi][sli] = d[sli][smi] = pathLength(sub)
    return d,p

# %%
def roundtrips(x, n):
    
    def isElem(x, l):
        for i in range(len(l)):
            if l[i]==x:
                return True
        return False

    def startpoint(trips):
        for i in range(n):
            for t in trips:
                if isElem(i, t):
                    break
            else:
                return i
    
    def totalLength(trips):
        s=0
        for i in range(0, len(trips)):
            s += len(trips[i])-1
        return s

    trips = []
    while totalLength(trips)<n:
        start = startpoint(trips)
        trip = [ start ]
        i = start
        while len(trip) < n-totalLength(trips):
            for j in range(0, n):
                if pulp.value(x[i][j])==1:
                    trip.append(j)
                    i=j
                    break        
            if pulp.value(x[trip[-1]][start])==1:
                trip.append(start)
                break
        trips.append(trip)
    return sorted(trips, key=lambda t: len(t), reverse=True)

# %%
import time

def createLoop(M, T, timing=False):
    
    if timing:
        start_time = time.time()
        last_time = time.time()
        
    D, P = createTables(M, T)   # These are the distances between customers and warehouse only
    
    if timing:
        print(f"createTables:   {time.time()-start_time:6.2f}s")
        last_time = time.time()
        
    n = len(T)

    if n==1:
        return T
        
    # create variables
    x = pulp.LpVariable.dicts("x", ( range(n), range(n) ),
                            lowBound=0, upBound=1, cat=pulp.LpInteger)
    # create problem
    prob = pulp.LpProblem("Loop",pulp.LpMinimize)
    # add objective function
    prob += pulp.lpSum([ D[i][j]*x[i][j] 
                             for i in range(n) for j in range(n) ])
    # add constraints
    constraints=0
    for j in range(n):
        prob += pulp.lpSum([ x[i][j] for i in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        prob += pulp.lpSum([ x[i][j] for j in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        for j in range(n):
            if i!=j:
                prob += x[i][j]+x[j][i] <= 1
                constraints += 1
    # initialise solver
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=0)
    prob.solve(solver)

    if timing:
        print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
        last_time = time.time()

    trips = roundtrips(x, n)
    while len(trips)>1:
        longest = max([ len(t) for t in trips ])
        for t in trips:
            if len(t)<longest:
                prob += pulp.lpSum([ x[t[i]][t[i+1]] + x[t[i+1]][t[i]]
                                        for i in range(0,len(t)-1) ]) <= len(t)-2
                constraints += 1
            else:
                longest = math.inf
        prob.solve(solver)
        
        if timing:
            print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
            last_time = time.time()

        trips = roundtrips(x, n)
        
    trip = trips[0]
    loop = []
    for k in range(len(trip)-1):
        sub = P[trip[k]][trip[k+1]]
        loop += sub if len(loop)==0 else sub[1:]
        
    if timing:
        print(f"createLoop:     {time.time()-start_time:6.2f}s")

    return loop

# %% [markdown]
# ## Heuristic Algorithm

# %%
def FW(M):
    
    V, E = M

    n = len(V)
    d = [ [ math.inf for j in range(n) ] for i in range(n) ]
    p = [ [ None for j in range(n) ] for i in range(n) ]

    for (A, B) in E:
        a = V.index(A)
        b = V.index(B)
        d[a][b] = d[b][a] = dist(A, B)
        p[a][b] = [A, B]
        p[b][a] = [B, A]
    
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [V[i]]
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dk = d[i][k] + d[k][j]
                if d[i][j] > dk:
                    d[i][j] = dk
                    p[i][j] = p[i][k][:-1] + p[k][j]
                    
    return d, p

# %%
def createLoopH(M, T, plot=False, timing=False):
    
    def makeLoop(L):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop
    
    def ruleTwoChange(route, i, k):
        new_route = route[:i] + route[i:k+1][::-1] + route[k+1:]
        return new_route
    
    def rulethreeChange(route, i, j):
        removed = route[j + 1]
        new_route = route[:j+1] + route[j+2:]
        new_route = new_route[:i+1] + [removed] + new_route[i+1:]
        return new_route

    if timing:
        start_time = time.time()
        
    V, E = M
    D, P = FW(M)   # note these are the distances between all vertices in M (and T)
    
    if timing:
        print(f"Floyd-Warshall: {time.time()-start_time:6.2f}s")
        
    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            if plot:
                loop = makeLoop(L)
                plotMap(M, T=L, P=loop, W=W, 
                        grid=True, text=f"{pathLength(loop):,d}m")
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    
                    
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]
        
    # Rule 2
    improved = True
    while improved:
        improved = False
        for i in range(len(L)-2):
            for j in range(i+2, len(L)-1):
                if D[V.index(L[i])][V.index(L[i+1])] + D[V.index(L[j])][V.index(L[j+1])] > \
                   D[V.index(L[i])][V.index(L[j])] + D[V.index(L[i+1])][V.index(L[j+1])]:
                    L = ruleTwoChange(L, i+1, j)
                    improved = True
                    break
            if improved:
                break
        
    
    # Rule 3
    improved = True
    while improved:
        improved = False
        for i in range(len(L) - 1):
            for j in range(len(L) - 2):
                if i - j == 1 or i == j:
                    continue
                diff = D[V.index(L[i])][V.index(L[i+1])] + D[V.index(L[j])][V.index(L[j+1])] + D[V.index(L[j+1])][V.index(L[j+2])] - (D[V.index(L[i])][V.index(L[j+1])] + D[V.index(L[j+1])][V.index(L[i+1])] + D[V.index(L[j])][V.index(L[j+2])])
                if diff > 0 and pathLength(makeLoop(L)) - pathLength(makeLoop(rulethreeChange(L, i, j))) == diff:
                    # print(i, j, diff)
                    L = rulethreeChange(L, i, j)
                    improved = True
                    break
            if improved:
                break
    
    if timing:
        print(f"createLoopH:    {time.time()-start_time:6.2f}s")
        
    return makeLoop(L)

# %% [markdown]
# # Class Recorder

# %% [markdown]
# We willl use a class Recorder as a reference point for capturing data during the simulation. There will be only one recorder. It will be created at the beginning of every simulation run. Every entity will carry a reference to the Recorder.

# %%
class Recorder:
    
    def __init__(self, env, M, W, C, days, 
                 log=False, plot=False, timing=False):
        self.env = env
        self.M = M
        self.W = W
        self.C = C
        self.days = days
        self.log = log
        self.plot = plot
        
        self.timing = timing
        self.start_time = time.time()
        self.last_time = self.start_time
        self.cum_timer = {}

        Customer.REGISTER = []
        Parcel.REGISTER = []

        # create a data frame for records per working day
        self.daily = pd.DataFrame()
        self.daily['begin work at'] = [None]*days
        self.daily['end work at'] = [None]*days
        self.daily['dist'] = [None]*days
        self.daily['left'] = [None]*days

    def timer(self, s):
        t = time.time()
        Δt = t-self.last_time
        if self.timing:
            print(f"==== t: {t-self.start_time:6.2f}s "
                  f"Δt: {Δt:6.2f}s [{s:s}]")
        if s in self.cum_timer:
            self.cum_timer[s] += Δt
        else:
            self.cum_timer[s] = Δt
        self.last_time = t

    def reportTimer(self):
        print(f"==== t: {self.total_time:6.2f}s Total")
        for k in sorted(self.cum_timer, key=lambda x: self.cum_timer[x], reverse=True):
            print(f"==== ΣΔt: {self.cum_timer[k]:6.2f}s "+ k)

    def trace(self, event):
        if self.log:
            print(timestamp(self.env.now), event)

    def recordDriverBeginsWork(self):
        self.trace("Driver arrives for work")
        self.daily.at[day(self.env.now), 'begin work at'] = int(round(self.env.now))
        
    def recordDriverEndsWork(self):
        self.trace("Driver goes home")
        self.daily.at[day(self.env.now), 'end work at'] = int(round(self.env.now))
    
    def recordTourLength(self, length):
        self.daily.at[day(self.env.now), 'dist'] = int(length)

    def recordParcelsLeftOver(self, numberOfParcels):
        self.trace(f"{numberOfParcels:d} left over for next day")
        self.daily.at[day(self.env.now), 'left'] = numberOfParcels

    def finish(self):
        # simulation is finished for good
        # by removing the simulation environment we can
        # pickle recorder
        self.env = None
        self.total_time = time.time()-self.start_time
        self.daily['working time'] = (self.daily['end work at']-self.daily['begin work at'])//60

        
    def __stats__(self, column):
        d = self.daily[column].copy()
        return d.mean(), d.median(), d.std()
        
    def statsWorkingTime(self):
        return self.__stats__('working time')
        
    def histWorkingTime(self):
        histplot(self.daily['working time'],
                 xlabel='Working Time [min]',
                 title='Daily Working Time')
        
    def plotWorkingTime(self):
        dailyPlot(self.daily['working time'],
                  ylabel='Working Time [min]',
                  title='Daily Working Time')

    def statsTourLength(self):
        return self.__stats__('dist')
        
    def histTourLength(self):
        histplot(self.daily['dist'],
                 xlabel='Tour Length [m]',
                 title='Daily Tour Length')
            
    def plotTourLength(self):
        dailyPlot(self.daily['dist'],
                  ylabel='Tour Length [m]',
                  title='Daily Tour Length')

    def statsLeftOver(self):
        return self.__stats__('left')
        
    def histLeftOver(self):
        histplot(self.daily['left'],
                 xlabel='Left-Over Parcels',
                 title='Daily Left-Over Parcels')
                
    def plotLeftOver(self):
        dailyPlot(self.daily['left'],
                  ylabel='Number of Parcels',
                  title='Daily Left-Over Parcels')

# %% [markdown]
# # Class Parcel

# %% [markdown]
# <img src='img/EventGraph Parcel.png' width=500/>

# %% [markdown]
# Parcels follow through a sequence of states:
# - processing
# - in transit (from manufacture to distribution centre)
# - arrived in distribution centre
# - ready for delivery
# - out for delivery
# - customer not present
# - returned to distribution centre
# - delivered

# %%
class Parcel:
    
    REGISTER = []
    
    def __init__(self, rec, i, cust, custIndex):
        self.rec = rec
        self.i = i  # row index in data frames of input data
        self.dest = cust.location
        self.custIndex = custIndex
        self.status = [ 'processing' ] # status record and
        self.timing = [ self.rec.env.now ]      # timing
        assert(len(Parcel.REGISTER)==i)
        Parcel.REGISTER += [ self ] 
    
    # factory method ensures that there is only
    # one Parcel per location
    def getParcel(rec, i, location, custIndex):
        for p in Parcel.REGISTER:
            if p.i == i:
                return p
        return Parcel(rec, i, location, custIndex)

    
    def __str__(self):
        return f"Parcel: {self.i:3d} ({self.custIndex:3d})"

    def index(self):
        return self.i
    
    def destination(self):
        return self.dest
    
    def __reg(self, state):
        self.status += [ state ]
        self.timing += [ self.rec.env.now ]
        self.rec.trace(str(self)+" "+state)
        
    def arrivedAtDeliveryCentre(self):
        self.__reg('arr at delivery centre')
        
    def outForDelivery(self): 
        self.__reg('out for delivery')
        
    def returnFromDelivery(self):
        self.__reg('return from delivery')

# %% [markdown]
# # Class Customer

# %% [markdown]
# <img src='img/EventGraph Customer.png' width=500/>

# %%
class Customer:
    
    REGISTER = []

    def __init__(self, rec, location):
        self.rec = rec
        self.location = location
        self.i = len(Customer.REGISTER)
        Customer.REGISTER += [ self ]
        self.atHome = True
        self.answersDoor = False
        self.parcelsReceived = []
        rec.env.process(self.process())
        
    def __str__(self):
        return f"Customer: {self.i:2d} {str(self.location):s}"
    
    # factory method ensures that there is only
    # one customer per location
    def getCustomer(rec, location):
        for c in Customer.REGISTER:
            if c.location == location:
                return c
        return Customer(rec, location)
    
    def leaveHouse(self):
        assert(self.atHome and not self.answersDoor)
        # self.rec.trace(str(self)+" leaves house")
        self.atHome = False
     
    def returnHome(self):
        assert(not self.atHome)
        # self.rec.trace(str(self)+" returns home")
        self.atHome = True
        
    def answerDoor(self):
        if self.atHome:
            yield self.rec.env.timeout(random.expovariate(1/AVERAGE_TIME_ANSWER_DOOR))
            self.rec.trace(str(self)+" answers door")
            self.answersDoor = True
        else:
            yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
            self.rec(str(self)+" not at home")
            
    def acceptParcel(self, parcel):
        assert(self.answersDoor)
        self.parcelsReceived += [parcel]
        self.rec.trace(str(self)+" accepts "+str(parcel))
        
    def signOff(self):
        assert(self.answersDoor)
        self.rec.trace(str(self)+" signs off")
        self.answersDoor = False
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 8))
        while day(self.rec.env.now)<self.rec.days:
            # in a refinement we may use random times
            self.leaveHouse()
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))
            self.returnHome()
            yield self.rec.env.timeout(nextHour(self.rec.env, 8))

# %% [markdown]
# # Class Driver

# %% [markdown]
# <img src='img/EventGraph Driver.png' width=500/>

# %%
class Driver:
    
    def __init__(self, rec, DC):
        self.rec = rec
        self.DC = DC
        self.location = None
        self.parcels = None
        self.tour = None
        self.rec.env.process(self.process())
        
    # activity
    def __drive(self, target):
        assert(self.tour[0] == self.location)
        while self.location!=target:
            d = dist(self.location, self.tour[1])
            yield self.rec.env.timeout(d / AVERAGE_SPEED)
            self.location = self.tour[1]
            self.tour = self.tour[1:]
        assert(self.tour[0] == self.location == target)
    
    def arriveForWork(self):
        self.location = self.DC.W
        self.parcels = []
        self.returns = []
        self.tour = [ self.DC.W ]
        self.rec.recordDriverBeginsWork()
        
    def leaveForDelivery(self, tour, parcels):
        self.tour, self.parcels = tour, parcels
        self.rec.trace(f"Driver leaves for delivery " \
                       f"of {len(parcels):d} parcels")
        
    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 18))
        while day(self.rec.env.now)<self.rec.days:
            self.arriveForWork()
            tour, parcels = self.DC.sendForDelivery()
            yield self.rec.env.timeout(PREP_TIME_PER_PARCEL*len(parcels))
            self.rec.recordTourLength(pathLength(tour))
            self.leaveForDelivery(tour, parcels)        
            while len(self.parcels)>0:
                # drive to customer
                custLocation = self.parcels[0].dest
                cust = Customer.getCustomer(self.rec, custLocation)
                self.rec.trace("Driver drives to "+str(cust))
                yield from self.__drive(custLocation)
                self.rec.trace("Driver arrived at "+str(cust))
                # call at customer
                yield from cust.answerDoor()
                
                if cust.answersDoor:
                    while len(self.parcels)>0 and \
                            custLocation == self.parcels[0].dest:
                        cust.acceptParcel(self.parcels[0])
                        yield self.rec.env.timeout(random.expovariate(1/10))
                        self.parcels = self.parcels[1:]
                    cust.signOff()
                    yield self.rec.env.timeout(random.expovariate(1/10))
                else:
                    while len(self.parcels)>0 and  \
                            custLocation == self.parcels[0].dest:
                        self.returns += self.parcels[0]
                        self.parcels = self.parcels[1:]

            # return to delivery centre
            self.rec.trace("Driver returns to delivery centre")
            yield from self.__drive(self.DC.W)
            self.rec.trace("Driver arrived at delivery centre")
            
            for parcel in self.returns:
                self.DC.returnFromDelivery(parcel)
                yield self.rec.env.timeout(RETURN_TIME_PER_PARCEL)
            yield self.rec.env.timeout(600)
                    
            self.rec.recordParcelsLeftOver(len(self.DC.parcels)+
                                           len(self.DC.leftOver))

            self.rec.recordDriverEndsWork()
            
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))

# %% [markdown]
# # Class Delivery Centre

# %% [markdown]
# <img src="img/EventGraph Delivery Centre.png" width=300/>

# %%
class DeliveryCentre:
    
    def __init__(self, rec, M, W):
        self.rec = rec
        self.M = M
        self.W = W
        self.limit = 35000
        
        self.leftOver = []    # list of parcels
        self.parcels = []     # list of parcels scheduled for delivery
        self.dest = []        # list of unique customer destinations
        self.tour = None      # tour planned for delivery
    
    def __accept(self, parcel):
        custLoc = parcel.dest
        if custLoc not in self.dest:
            MT = addTargets(self.M, self.dest + [custLoc])
            self.rec.timer("addTarget")
            SH = createLoopH(MT, [self.W] + self.dest + [custLoc], 
                             timing=self.rec.timing)
            self.rec.timer("createLoopH")
            if self.tour is None and pathLength(SH)<self.limit:
                self.parcels.append(parcel)
                self.dest += [custLoc]
            else: 
                S = createLoop(MT, [self.W] + self.dest + [custLoc], 
                               timing=self.rec.timing)
                self.rec.timer("createLoop")
                if pathLength(S)<self.limit:
                    self.parcels.append(parcel)
                    self.dest += [custLoc]
                    self.tour = S
                else:
                    self.leftOver.append(parcel)
        else:
            self.parcels.append(parcel)
        
    def acceptParcel(self, parcel):
        parcel.arrivedAtDeliveryCentre()
        self.__accept(parcel)
            
    def sendForDelivery(self):
        parcels = []
        if self.tour is None:
            MT = addTargets(self.M, self.dest)
            self.rec.timer("addTarget")
            self.tour = createLoop(MT, [self.W] + self.dest, 
                                   timing=self.rec.timing)
            self.rec.timer("createLoop")
        tour = self.tour
        addresses = self.dest
        
        # pick parcels in sequence to be delivered
        for i in range(1, len(tour)-1):
            dest = tour[i]
            for p in self.parcels:
                if p.dest == dest and p not in parcels:
                    parcels += [p]
                    p.outForDelivery()
         
        # arrange the left overs
        L = self.leftOver
        self.tour = None
        self.parcels = []
        self.leftOver = []
        self.dest = []
        for p in L:
            self.__accept(p)
        
        if self.rec.plot:
            plotMap(self.rec.M, T=addresses, P=tour, W=tour[0], 
                    text=f"Day {day(self.rec.env.now):2d}, {pathLength(tour):,d}m")

        return tour, parcels
                 
    def returnFromDelivery(self, parcel):
        parcel.returnFromDelivery()
        self.__accept(parcel)

    def getInventory(self):
        return len(self.parcels)+len(self.leftOver)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Parameters from Specification

# %% [markdown]
# The time required for driving is based on the distance between way points at an average speed of 15km/h.

# %%
AVERAGE_SPEED = 15/3.6

# %% [markdown]
# The **cumulative preparation time** (route planning and
# sorting of the parcels in the delivery order and
# packing the cargo-bike) is assumed to be 50 sec per
# parcel to be delivered.

# %%
PREP_TIME_PER_PARCEL = 50

# %% [markdown]
# **Additional assumption:** The time to **process returned parcels** in the delivery centre is 30 sec per parce.

# %%
RETURN_TIME_PER_PARCEL = 30

# %% [markdown]
# The average time to answer the door.

# %%
AVERAGE_TIME_ANSWER_DOOR = 40

# %%
WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR = 60

# %% [markdown]
# ## Generate Input Data

# %%
def generateDeliveryData(p, C, days, seed=0):
    ## p is the average number of parcels per day per customer
    ## C is the number of customers to be served
    ## days is the number of days for which data are to be generated.
    np.random.seed(seed)
    R = np.random.poisson(lam=len(C)*p, size=days)
    D = [ sorted(list(np.random.choice(range(len(C)), size=i))) for i in R ]
    return D

# %%
def generateInputData(D, log=False):

    R = [ len(d) for d in D ]
    N = sum(R)
    
    DAY_LENGTH = 24*3600    # measured in minutes
    DAY_START = 8*3600      # first delivery in the morning
    DAY_END = 17*3600     # last delivery during day time

    x = pd.DataFrame()

    x['iarr'] = [None]*N
    x['time'] = [None]*N
    x['day'] = [None]*N
    x['dest'] = [None]*N

    current_day = 0
    last_time = 0
    i = 0

    for d in D: # for each day

        if log:
            print("generating for day: ",current_day, D[current_day])
            
        time = current_day*DAY_LENGTH + DAY_START 

        for c in d: # for each customer that should get a 

            IARR = (DAY_END-DAY_START-2*3600) / len(d)  # estimated average IAT for the current day

            iat = random.expovariate(1.0/IARR)
            new_time = time + iat

            x.at[i, 'iarr'] = round(new_time - last_time,1)
            x.at[i, 'time'] = round(new_time - current_day*DAY_LENGTH , 1)
            x.at[i, 'day'] = current_day
            x.at[i, 'dest'] = c
            
            i += 1
            last_time = time = new_time
    
        current_day += 1
    
    return x

# %% [markdown]
# ## Simulation Routine

# %%
def simulation(M, W, C, p=0.2, days=10, seed=0, log=False, plot=False, timing=False):
        
    random.seed(seed)
    D = generateDeliveryData(p, C, days, seed)
    X = generateInputData(D, log=log)
    
    env = simpy.Environment()
    rec = Recorder(env, M, W, C, days, log=log, plot=plot, timing=timing)

    print(f"Simulating delivery of {len(X):d} parcels "
          f"over {len(D):d} days to {len(C):d} customers")

    for c in C:
        Customer.getCustomer(rec, c)           
    DC = DeliveryCentre(rec, M, W)
    D = Driver(rec, DC)

    def generatorProcess(env):
        # generate the parcels based on input data x
        for i in range(len(X)):
            yield env.timeout(X.at[i, 'iarr'])
            custIndex = X.at[i, 'dest']
            custLoc = C[custIndex]
            cust = Customer.getCustomer(rec, custLoc)
            p = Parcel.getParcel(rec, i, cust, custIndex)
            DC.acceptParcel(p)

    env.process(generatorProcess(env))
    env.run()

    rec.finish()

    if log:
        print(f"Delivery Centre Inventory: {DC.getInventory():d} parcels")

    return rec

# %% [markdown]
# ## Small Simulation Run

# %%
import pickle
with open('data.pickled', 'rb') as f:
    M, C = pickle.load(f)

# %%
random.seed(0)
W = generateWarehouseLocation(M)

rec = simulation(M, W, C, p=0.15, days=20, log=True)
with open(f'rec.pickle', 'wb') as f:
    pickle.dump(rec, f)
# Out:
# generating for day:  0 [6, 23, 47, 48, 49, 53, 68, 69, 78, 84, 85, 95, 99, 100, 117, 121, 127, 131, 140, 141, 142, 143, 148]
# generating for day:  1 [0, 0, 23, 36, 42, 43, 48, 62, 82, 93, 94, 98, 98, 112, 113, 114, 121, 123, 127, 127, 130, 131, 138, 149]
# generating for day:  2 [2, 10, 11, 14, 19, 32, 36, 38, 41, 42, 43, 50, 51, 58, 77, 80, 86, 104, 115, 128, 148]
# generating for day:  3 [2, 3, 4, 13, 14, 19, 24, 30, 40, 61, 67, 72, 72, 86, 94, 95, 96, 107, 112, 121, 125, 139]
# generating for day:  4 [3, 11, 11, 13, 16, 18, 24, 25, 31, 32, 35, 40, 41, 43, 44, 67, 70, 71, 75, 79, 83, 93, 104, 104, 109, 110, 111, 117, 118, 118, 121, 121, 125, 129, 149]
# generating for day:  5 [2, 3, 9, 27, 27, 29, 31, 35, 39, 41, 44, 46, 51, 53, 61, 67, 73, 85, 97, 108, 111, 125, 131, 137, 138, 138, 148]
# generating for day:  6 [0, 25, 30, 33, 34, 34, 35, 35, 36, 36, 67, 80, 88, 91, 103, 112, 114, 116, 120, 126, 129, 133, 136]
# generating for day:  7 [2, 17, 29, 33, 44, 66, 69, 84, 91, 101, 111, 117, 140, 146]
# generating for day:  8 [16, 18, 24, 28, 39, 41, 43, 51, 63, 73, 83, 85, 89, 92, 93, 94, 105, 106, 116, 128, 145, 149]
# generating for day:  9 [13, 25, 32, 58, 64, 72, 81, 87, 87, 91, 93, 116, 120, 123, 136, 147]
# generating for day:  10 [0, 4, 5, 14, 20, 22, 26, 28, 61, 68, 83, 92, 122, 135, 136, 139, 141]
# generating for day:  11 [13, 18, 18, 34, 44, 48, 51, 51, 52, 53, 55, 58, 58, 59, 70, 74, 80, 87, 94, 105, 106, 117, 124]
# generating for day:  12 [4, 6, 8, 13, 22, 24, 38, 49, 56, 60, 70, 79, 87, 100, 114, 121, 135, 136, 144]
# generating for day:  13 [3, 7, 20, 29, 30, 42, 53, 54, 65, 83, 86, 97, 101, 105, 115, 117, 119, 120, 126, 128, 137, 148]
# generating for day:  14 [9, 18, 20, 36, 43, 58, 63, 68, 74, 76, 83, 91, 91, 104, 111, 112, 113, 113, 128, 129, 131, 138, 140, 148]
# generating for day:  15 [0, 3, 7, 24, 26, 28, 36, 39, 46, 67, 68, 69, 71, 72, 83, 84, 84, 91, 94, 99, 102, 107, 108, 109, 121, 125, 133, 134, 135, 135, 136, 149]
# generating for day:  16 [0, 26, 32, 38, 57, 59, 74, 83, 87, 89, 91, 93, 96, 97, 104, 115, 123, 132, 145, 148]
# generating for day:  17 [4, 6, 15, 22, 26, 46, 47, 51, 53, 61, 71, 73, 82, 87, 90, 94, 98, 104, 105, 109, 118, 119, 128, 138, 141]
# generating for day:  18 [3, 12, 28, 34, 65, 65, 66, 66, 70, 78, 80, 88, 88, 92, 93, 100, 112, 114, 114, 120, 125, 134, 135, 138, 148]
# generating for day:  19 [21, 25, 35, 66, 73, 77, 81, 92, 100, 101, 102, 109, 115, 123, 134, 136, 144, 149]
# Simulating delivery of 452 parcels over 20 days to 150 customers
# [ 0] 08:33:58.5 Parcel:   0 (  6) arr at delivery centre
# [ 0] 08:59:52.8 Parcel:   1 ( 23) arr at delivery centre
# [ 0] 09:09:50.7 Parcel:   2 ( 47) arr at delivery centre
# [ 0] 09:15:19.0 Parcel:   3 ( 48) arr at delivery centre
# [ 0] 09:28:23.5 Parcel:   4 ( 49) arr at delivery centre
# [ 0] 09:37:52.1 Parcel:   5 ( 53) arr at delivery centre
# [ 0] 10:05:50.1 Parcel:   6 ( 68) arr at delivery centre
# [ 0] 10:12:26.1 Parcel:   7 ( 69) arr at delivery centre
# [ 0] 10:24:15.5 Parcel:   8 ( 78) arr at delivery centre
# [ 0] 10:40:14.8 Parcel:   9 ( 84) arr at delivery centre
# [ 0] 11:23:50.3 Parcel:  10 ( 85) arr at delivery centre
# [ 0] 11:36:40.1 Parcel:  11 ( 95) arr at delivery centre
# [ 0] 11:42:42.8 Parcel:  12 ( 99) arr at delivery centre
# [ 0] 12:08:27.4 Parcel:  13 (100) arr at delivery centre
# [ 0] 12:26:02.8 Parcel:  14 (117) arr at delivery centre
# [ 0] 12:31:18.7 Parcel:  15 (121) arr at delivery centre
# [ 0] 13:15:13.9 Parcel:  16 (127) arr at delivery centre
# [ 0] 14:29:24.4 Parcel:  17 (131) arr at delivery centre
# [ 0] 14:59:45.2 Parcel:  18 (140) arr at delivery centre
# [ 0] 15:42:12.0 Parcel:  19 (141) arr at delivery centre
# [ 0] 15:48:58.8 Parcel:  20 (142) arr at delivery centre
# [ 0] 16:12:52.7 Parcel:  21 (143) arr at delivery centre
# [ 0] 16:54:42.9 Parcel:  22 (148) arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel:  11 ( 95) out for delivery
# [ 0] 18:00:00.0 Parcel:   0 (  6) out for delivery
# [ 0] 18:00:00.0 Parcel:   1 ( 23) out for delivery
# [ 0] 18:00:00.0 Parcel:   3 ( 48) out for delivery
# [ 0] 18:00:00.0 Parcel:   9 ( 84) out for delivery
# [ 0] 18:00:00.0 Parcel:  10 ( 85) out for delivery
# [ 0] 18:00:00.0 Parcel:  13 (100) out for delivery
# [ 0] 18:00:00.0 Parcel:  14 (117) out for delivery
# [ 0] 18:00:00.0 Parcel:  15 (121) out for delivery
# [ 0] 18:00:00.0 Parcel:  20 (142) out for delivery
# [ 0] 18:00:00.0 Parcel:  21 (143) out for delivery
# [ 0] 18:00:00.0 Parcel:  18 (140) out for delivery
# [ 0] 18:00:00.0 Parcel:  16 (127) out for delivery
# [ 0] 18:00:00.0 Parcel:  19 (141) out for delivery
# [ 0] 18:00:00.0 Parcel:  17 (131) out for delivery
# [ 0] 18:00:00.0 Parcel:  12 ( 99) out for delivery
# [ 0] 18:00:00.0 Parcel:   8 ( 78) out for delivery
# [ 0] 18:00:00.0 Parcel:   5 ( 53) out for delivery
# [ 0] 18:00:00.0 Parcel:   4 ( 49) out for delivery
# [ 0] 18:00:00.0 Parcel:   2 ( 47) out for delivery
# [ 0] 18:00:00.0 Parcel:   6 ( 68) out for delivery
# [ 0] 18:00:00.0 Parcel:   7 ( 69) out for delivery
# [ 0] 18:18:20.0 Driver leaves for delivery of 22 parcels
# [ 0] 18:18:20.0 Driver drives to Customer: 95 (4747, 4560)
# [ 0] 18:28:47.1 Driver arrived at Customer: 95 (4747, 4560)
# [ 0] 18:29:51.3 Customer: 95 (4747, 4560) answers door
# [ 0] 18:29:51.3 Customer: 95 (4747, 4560) accepts Parcel:  11 ( 95)
# [ 0] 18:30:16.2 Customer: 95 (4747, 4560) signs off
# [ 0] 18:30:36.8 Driver drives to Customer:  6 (939, 5120)
# [ 0] 18:46:46.2 Driver arrived at Customer:  6 (939, 5120)
# [ 0] 18:47:31.9 Customer:  6 (939, 5120) answers door
# [ 0] 18:47:31.9 Customer:  6 (939, 5120) accepts Parcel:   0 (  6)
# [ 0] 18:47:48.5 Customer:  6 (939, 5120) signs off
# [ 0] 18:47:55.8 Driver drives to Customer: 23 (1995, 6240)
# [ 0] 18:56:38.0 Driver arrived at Customer: 23 (1995, 6240)
# [ 0] 18:57:39.6 Customer: 23 (1995, 6240) answers door
# [ 0] 18:57:39.6 Customer: 23 (1995, 6240) accepts Parcel:   1 ( 23)
# [ 0] 18:57:41.7 Customer: 23 (1995, 6240) signs off
# [ 0] 18:57:56.9 Driver drives to Customer: 48 (2732, 7360)
# [ 0] 19:05:22.6 Driver arrived at Customer: 48 (2732, 7360)
# [ 0] 19:05:46.1 Customer: 48 (2732, 7360) answers door
# [ 0] 19:05:46.1 Customer: 48 (2732, 7360) accepts Parcel:   3 ( 48)
# [ 0] 19:06:00.3 Customer: 48 (2732, 7360) signs off
# [ 0] 19:49:19.3 Driver drives to Customer: 127 (6425, 4560)
# [ 0] 19:51:44.7 Driver arrived at Customer: 127 (6425, 4560)
# [ 0] 19:52:44.2 Customer: 127 (6425, 4560) answers door
# [ 0] 19:52:44.2 Customer: 127 (6425, 4560) accepts Parcel:  16 (127)
# [ 0] 19:52:57.4 Customer: 127 (6425, 4560) signs off
# [ 0] 19:52:57.7 Driver drives to Customer: 141 (7104, 3440)
# [ 0] 20:00:09.5 Driver arrived at Customer: 141 (7104, 3440)
# [ 0] 20:00:33.2 Customer: 141 (7104, 3440) answers door
# [ 0] 20:00:33.2 Customer: 141 (7104, 3440) accepts Parcel:  19 (141)
# [ 0] 20:00:44.8 Customer: 141 (7104, 3440) signs off
# [ 0] 20:00:45.1 Driver drives to Customer: 131 (6587, 3440)
# [ 0] 20:02:49.2 Driver arrived at Customer: 131 (6587, 3440)
# [ 0] 20:04:29.8 Customer: 131 (6587, 3440) answers door
# [ 0] 20:04:29.8 Customer: 131 (6587, 3440) accepts Parcel:  17 (131)
# [ 0] 20:05:02.6 Customer: 131 (6587, 3440) signs off
# [ 0] 20:05:15.4 Driver drives to Customer: 99 (4860, 940)
# [ 0] 20:21:33.2 Driver arrived at Customer: 99 (4860, 940)
# [ 0] 20:21:36.5 Customer: 99 (4860, 940) answers door
# [ 0] 20:21:36.5 Customer: 99 (4860, 940) accepts Parcel:  12 ( 99)
# [ 0] 20:21:37.2 Customer: 99 (4860, 940) signs off
# [ 0] 20:21:41.6 Driver drives to Customer: 78 (3914, 1845)
# [ 0] 20:30:21.7 Driver arrived at Customer: 78 (3914, 1845)
# [ 0] 20:30:22.9 Customer: 78 (3914, 1845) answers door
# [ 0] 20:30:22.9 Customer: 78 (3914, 1845) accepts Parcel:   8 ( 78)
# [ 0] 20:30:27.2 Customer: 78 (3914, 1845) signs off
# [ 0] 20:30:27.3 Driver drives to Customer: 53 (2880, 2004)
# [ 0] 20:36:38.6 Driver arrived at Customer: 53 (2880, 2004)
# [ 0] 20:39:05.1 Customer: 53 (2880, 2004) answers door
# [ 0] 20:39:05.1 Customer: 53 (2880, 2004) accepts Parcel:   5 ( 53)
# [ 0] 20:39:22.1 Customer: 53 (2880, 2004) signs off
# [ 0] 20:39:22.9 Driver drives to Customer: 49 (2880, 865)
# [ 0] 20:43:56.2 Driver arrived at Customer: 49 (2880, 865)
# [ 0] 20:45:25.8 Customer: 49 (2880, 865) answers door
# [ 0] 20:45:25.8 Customer: 49 (2880, 865) accepts Parcel:   4 ( 49)
# [ 0] 20:45:28.1 Customer: 49 (2880, 865) signs off
# [ 0] 20:45:30.4 Driver drives to Customer: 47 (2715, 1200)
# [ 0] 20:47:30.4 Driver arrived at Customer: 47 (2715, 1200)
# [ 0] 20:48:15.2 Customer: 47 (2715, 1200) answers door
# [ 0] 20:48:15.2 Customer: 47 (2715, 1200) accepts Parcel:   2 ( 47)
# [ 0] 20:48:43.1 Customer: 47 (2715, 1200) signs off
# [ 0] 20:48:44.4 Driver drives to Customer: 68 (3440, 2667)
# [ 0] 20:57:30.5 Driver arrived at Customer: 68 (3440, 2667)
# [ 0] 20:57:30.8 Customer: 68 (3440, 2667) answers door
# [ 0] 20:57:30.8 Customer: 68 (3440, 2667) accepts Parcel:   6 ( 68)
# [ 0] 20:57:35.4 Customer: 68 (3440, 2667) signs off
# [ 0] 20:57:35.6 Driver drives to Customer: 69 (3440, 3085)
# [ 0] 20:59:15.9 Driver arrived at Customer: 69 (3440, 3085)
# [ 0] 20:59:53.1 Customer: 69 (3440, 3085) answers door
# [ 0] 20:59:53.1 Customer: 69 (3440, 3085) accepts Parcel:   7 ( 69)
# [ 0] 21:00:12.7 Customer: 69 (3440, 3085) signs off
# [ 0] 21:00:14.7 Driver returns to delivery centre
# [ 0] 21:03:54.3 Driver arrived at delivery centre
# [ 0] 21:13:54.3 1 left over for next day
# [ 0] 21:13:54.3 Driver goes home
# [ 1] 08:20:09.2 Parcel:  23 (  0) arr at delivery centre
# [ 1] 08:31:20.1 Parcel:  24 (  0) arr at delivery centre
# [ 1] 08:33:11.5 Parcel:  25 ( 23) arr at delivery centre
# [ 1] 08:43:09.3 Parcel:  26 ( 36) arr at delivery centre
# [ 1] 08:59:40.5 Parcel:  27 ( 42) arr at delivery centre
# [ 1] 09:42:24.6 Parcel:  28 ( 43) arr at delivery centre
# [ 1] 10:41:54.0 Parcel:  29 ( 48) arr at delivery centre
# [ 1] 10:53:14.6 Parcel:  30 ( 62) arr at delivery centre
# [ 1] 11:28:19.6 Parcel:  31 ( 82) arr at delivery centre
# [ 1] 11:33:36.5 Parcel:  32 ( 93) arr at delivery centre
# [ 1] 12:02:13.1 Parcel:  33 ( 94) arr at delivery centre
# [ 1] 12:16:08.5 Parcel:  34 ( 98) arr at delivery centre
# [ 1] 12:16:23.3 Parcel:  35 ( 98) arr at delivery centre
# [ 1] 12:38:38.7 Parcel:  36 (112) arr at delivery centre
# [ 1] 12:47:33.0 Parcel:  37 (113) arr at delivery centre
# [ 1] 13:18:02.2 Parcel:  38 (114) arr at delivery centre
# [ 1] 13:37:20.5 Parcel:  39 (121) arr at delivery centre
# [ 1] 13:37:21.7 Parcel:  40 (123) arr at delivery centre
# [ 1] 13:49:16.1 Parcel:  41 (127) arr at delivery centre
# [ 1] 14:24:39.1 Parcel:  42 (127) arr at delivery centre
# [ 1] 14:29:32.7 Parcel:  43 (130) arr at delivery centre
# [ 1] 14:36:25.7 Parcel:  44 (131) arr at delivery centre
# [ 1] 15:12:11.7 Parcel:  45 (138) arr at delivery centre
# [ 1] 15:15:54.3 Parcel:  46 (149) arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel:  28 ( 43) out for delivery
# [ 1] 18:00:00.0 Parcel:  23 (  0) out for delivery
# [ 1] 18:00:00.0 Parcel:  24 (  0) out for delivery
# [ 1] 18:00:00.0 Parcel:  25 ( 23) out for delivery
# [ 1] 18:00:00.0 Parcel:  27 ( 42) out for delivery
# [ 1] 18:00:00.0 Parcel:  26 ( 36) out for delivery
# [ 1] 18:00:00.0 Parcel:  29 ( 48) out for delivery
# [ 1] 18:00:00.0 Parcel:  30 ( 62) out for delivery
# [ 1] 18:00:00.0 Parcel:  31 ( 82) out for delivery
# [ 1] 18:00:00.0 Parcel:  32 ( 93) out for delivery
# [ 1] 18:00:00.0 Parcel:  34 ( 98) out for delivery
# [ 1] 18:00:00.0 Parcel:  35 ( 98) out for delivery
# [ 1] 18:00:00.0 Parcel:  39 (121) out for delivery
# [ 1] 18:00:00.0 Parcel:  43 (130) out for delivery
# [ 1] 18:00:00.0 Parcel:  46 (149) out for delivery
# [ 1] 18:00:00.0 Parcel:  41 (127) out for delivery
# [ 1] 18:00:00.0 Parcel:  42 (127) out for delivery
# [ 1] 18:00:00.0 Parcel:  22 (148) out for delivery
# [ 1] 18:00:00.0 Parcel:  45 (138) out for delivery
# [ 1] 18:00:00.0 Parcel:  44 (131) out for delivery
# [ 1] 18:00:00.0 Parcel:  40 (123) out for delivery
# [ 1] 18:00:00.0 Parcel:  38 (114) out for delivery
# [ 1] 18:00:00.0 Parcel:  37 (113) out for delivery
# [ 1] 18:00:00.0 Parcel:  36 (112) out for delivery
# [ 1] 18:00:00.0 Parcel:  33 ( 94) out for delivery
# [ 1] 18:20:50.0 Driver leaves for delivery of 25 parcels
# [ 1] 18:20:50.0 Driver drives to Customer: 43 (2659, 4000)
# [ 1] 18:28:26.2 Driver arrived at Customer: 43 (2659, 4000)
# [ 1] 18:28:31.0 Customer: 43 (2659, 4000) answers door
# [ 1] 18:28:31.0 Customer: 43 (2659, 4000) accepts Parcel:  28 ( 43)
# [ 1] 18:28:35.2 Customer: 43 (2659, 4000) signs off
# [ 1] 18:29:07.2 Driver drives to Customer:  0 (640, 2564)
# [ 1] 18:41:37.4 Driver arrived at Customer:  0 (640, 2564)
# [ 1] 18:41:43.0 Customer:  0 (640, 2564) answers door
# [ 1] 18:41:43.0 Customer:  0 (640, 2564) accepts Parcel:  23 (  0)
# [ 1] 18:42:17.0 Customer:  0 (640, 2564) accepts Parcel:  24 (  0)
# [ 1] 18:42:21.4 Customer:  0 (640, 2564) signs off
# [ 1] 18:42:27.9 Driver drives to Customer: 23 (1995, 6240)
# [ 1] 19:01:16.3 Driver arrived at Customer: 23 (1995, 6240)
# [ 1] 19:01:30.2 Customer: 23 (1995, 6240) answers door
# [ 1] 19:01:30.2 Customer: 23 (1995, 6240) accepts Parcel:  25 ( 23)
# [ 1] 19:01:57.9 Customer: 23 (1995, 6240) signs off
# [ 1] 19:02:29.6 Driver drives to Customer: 42 (2611, 6240)
# [ 1] 19:04:57.4 Driver arrived at Customer: 42 (2611, 6240)
# [ 1] 19:05:37.8 Customer: 42 (2611, 6240) answers door
# [ 1] 19:05:37.8 Customer: 42 (2611, 6240) accepts Parcel:  27 ( 42)
# [ 1] 19:05:39.9 Customer: 42 (2611, 6240) signs off
# [ 1] 19:06:29.4 Driver drives to Customer: 36 (2320, 7047)
# [ 1] 19:10:53.0 Driver arrived at Customer: 36 (2320, 7047)
# [ 1] 19:10:57.3 Customer: 36 (2320, 7047) answers door
# [ 1] 20:39:46.3 Driver arrived at Customer: 112 (5489, 830)
# [ 1] 20:40:12.7 Customer: 112 (5489, 830) answers door
# [ 1] 20:40:12.7 Customer: 112 (5489, 830) accepts Parcel:  36 (112)
# [ 1] 20:40:15.0 Customer: 112 (5489, 830) signs off
# [ 1] 20:40:15.0 Driver drives to Customer: 94 (4739, 1760)
# [ 1] 20:46:06.1 Driver arrived at Customer: 94 (4739, 1760)
# [ 1] 20:46:54.1 Customer: 94 (4739, 1760) answers door
# [ 1] 20:46:54.1 Customer: 94 (4739, 1760) accepts Parcel:  33 ( 94)
# [ 1] 20:47:03.8 Customer: 94 (4739, 1760) signs off
# [ 1] 20:47:03.9 Driver returns to delivery centre
# [ 1] 20:56:44.4 Driver arrived at delivery centre
# [ 1] 21:06:44.4 0 left over for next day
# [ 1] 21:06:44.4 Driver goes home
# [ 2] 08:16:45.3 Parcel:  47 (  2) arr at delivery centre
# [ 2] 08:22:12.4 Parcel:  48 ( 10) arr at delivery centre
# [ 2] 09:30:45.7 Parcel:  49 ( 11) arr at delivery centre
# [ 2] 10:03:16.3 Parcel:  50 ( 14) arr at delivery centre
# [ 2] 10:15:09.3 Parcel:  51 ( 19) arr at delivery centre
# [ 2] 10:16:49.9 Parcel:  52 ( 32) arr at delivery centre
# [ 2] 10:24:32.8 Parcel:  53 ( 36) arr at delivery centre
# [ 2] 10:38:43.8 Parcel:  54 ( 38) arr at delivery centre
# [ 2] 11:32:44.5 Parcel:  55 ( 41) arr at delivery centre
# [ 2] 11:35:03.1 Parcel:  56 ( 42) arr at delivery centre
# [ 2] 11:51:04.7 Parcel:  57 ( 43) arr at delivery centre
# [ 2] 12:15:36.0 Parcel:  58 ( 50) arr at delivery centre
# [ 2] 12:31:27.4 Parcel:  59 ( 51) arr at delivery centre
# [ 2] 13:05:08.8 Parcel:  60 ( 58) arr at delivery centre
# [ 2] 13:20:41.4 Parcel:  61 ( 77) arr at delivery centre
# [ 2] 14:27:05.1 Parcel:  62 ( 80) arr at delivery centre
# [ 2] 14:45:34.2 Parcel:  63 ( 86) arr at delivery centre
# [ 2] 15:03:17.2 Parcel:  64 (104) arr at delivery centre
# [ 2] 15:15:03.7 Parcel:  65 (115) arr at delivery centre
# [ 2] 15:33:12.2 Parcel:  66 (128) arr at delivery centre
# [ 2] 15:42:55.4 Parcel:  67 (148) arr at delivery centre
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel:  55 ( 41) out for delivery
# [ 2] 18:00:00.0 Parcel:  59 ( 51) out for delivery
# [ 2] 18:00:00.0 Parcel:  58 ( 50) out for delivery
# [ 2] 18:00:00.0 Parcel:  54 ( 38) out for delivery
# [ 2] 18:00:00.0 Parcel:  60 ( 58) out for delivery
# [ 2] 18:00:00.0 Parcel:  57 ( 43) out for delivery
# [ 2] 18:00:00.0 Parcel:  52 ( 32) out for delivery
# [ 2] 18:00:00.0 Parcel:  48 ( 10) out for delivery
# [ 2] 18:00:00.0 Parcel:  47 (  2) out for delivery
# [ 2] 18:00:00.0 Parcel:  49 ( 11) out for delivery
# [ 3] 08:30:51.5 Parcel:  71 ( 13) arr at delivery centre
# [ 3] 08:48:58.2 Parcel:  72 ( 14) arr at delivery centre
# [ 3] 09:09:22.7 Parcel:  73 ( 19) arr at delivery centre
# [ 3] 09:21:44.1 Parcel:  74 ( 24) arr at delivery centre
# [ 3] 09:23:31.9 Parcel:  75 ( 30) arr at delivery centre
# [ 3] 09:50:35.2 Parcel:  76 ( 40) arr at delivery centre
# [ 3] 10:30:33.4 Parcel:  77 ( 61) arr at delivery centre
# [ 3] 11:19:36.0 Parcel:  78 ( 67) arr at delivery centre
# [ 3] 11:54:52.9 Parcel:  79 ( 72) arr at delivery centre
# [ 3] 12:38:29.7 Parcel:  80 ( 72) arr at delivery centre
# [ 3] 13:27:27.7 Parcel:  81 ( 86) arr at delivery centre
# [ 3] 13:42:18.7 Parcel:  82 ( 94) arr at delivery centre
# [ 3] 13:51:47.3 Parcel:  83 ( 95) arr at delivery centre
# [ 3] 14:15:06.7 Parcel:  84 ( 96) arr at delivery centre
# [ 3] 14:21:16.2 Parcel:  85 (107) arr at delivery centre
# [ 3] 14:53:08.4 Parcel:  86 (112) arr at delivery centre
# [ 3] 15:29:17.5 Parcel:  87 (121) arr at delivery centre
# [ 3] 16:12:19.5 Parcel:  88 (125) arr at delivery centre
# [ 3] 16:29:20.2 Parcel:  89 (139) arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel:  83 ( 95) out for delivery
# [ 3] 18:00:00.0 Parcel:  81 ( 86) out for delivery
# [ 3] 18:00:00.0 Parcel:  85 (107) out for delivery
# [ 3] 18:00:00.0 Parcel:  87 (121) out for delivery
# [ 3] 18:00:00.0 Parcel:  76 ( 40) out for delivery
# [ 3] 18:00:00.0 Parcel:  77 ( 61) out for delivery
# [ 3] 18:00:00.0 Parcel:  73 ( 19) out for delivery
# [ 3] 18:00:00.0 Parcel:  72 ( 14) out for delivery
# [ 3] 18:00:00.0 Parcel:  69 (  3) out for delivery
# [ 3] 18:00:00.0 Parcel:  68 (  2) out for delivery
# [ 3] 18:00:00.0 Parcel:  70 (  4) out for delivery
# [ 3] 18:00:00.0 Parcel:  71 ( 13) out for delivery
# [ 3] 18:00:00.0 Parcel:  75 ( 30) out for delivery
# [ 3] 18:00:00.0 Parcel:  74 ( 24) out for delivery
# [ 3] 18:00:00.0 Parcel:  78 ( 67) out for delivery
# [ 3] 18:00:00.0 Parcel:  79 ( 72) out for delivery
# [ 3] 18:00:00.0 Parcel:  80 ( 72) out for delivery
# [ 3] 18:00:00.0 Parcel:  82 ( 94) out for delivery
# [ 3] 18:00:00.0 Parcel:  84 ( 96) out for delivery
# [ 3] 18:15:50.0 Driver leaves for delivery of 19 parcels
# [ 3] 18:15:50.0 Driver drives to Customer: 95 (4747, 4560)
# [ 3] 18:26:17.1 Driver arrived at Customer: 95 (4747, 4560)
# [ 3] 18:27:11.8 Customer: 95 (4747, 4560) answers door
# [ 3] 18:27:11.8 Customer: 95 (4747, 4560) accepts Parcel:  83 ( 95)
# [ 3] 18:27:12.3 Customer: 95 (4747, 4560) signs off
# [ 3] 18:27:22.0 Driver drives to Customer: 86 (4154, 4965)
# [ 3] 18:30:24.4 Driver arrived at Customer: 86 (4154, 4965)
# [ 3] 18:30:25.4 Customer: 86 (4154, 4965) answers door
# [ 3] 18:30:25.4 Customer: 86 (4154, 4965) accepts Parcel:  81 ( 86)
# [ 3] 18:30:31.8 Customer: 86 (4154, 4965) signs off
# [ 3] 18:30:53.8 Driver drives to Customer: 107 (5325, 6594)
# [ 3] 18:44:07.7 Driver arrived at Customer: 107 (5325, 6594)
# [ 3] 18:44:08.1 Customer: 107 (5325, 6594) answers door
# [ 3] 18:44:08.1 Customer: 107 (5325, 6594) accepts Parcel:  85 (107)
# [ 3] 18:44:15.6 Customer: 107 (5325, 6594) signs off
# [ 3] 18:44:16.3 Driver drives to Customer: 121 (6047, 6607)
# [ 3] 18:48:21.1 Driver arrived at Customer: 121 (6047, 6607)
# [ 3] 18:49:41.8 Customer: 121 (6047, 6607) answers door
# [ 3] 18:49:41.8 Customer: 121 (6047, 6607) accepts Parcel:  87 (121)
# [ 3] 18:49:53.4 Customer: 121 (6047, 6607) signs off
# [ 3] 18:50:06.9 Driver drives to Customer: 40 (2549, 7360)
# [ 3] 19:06:53.5 Driver arrived at Customer: 40 (2549, 7360)
# [ 3] 19:07:37.7 Customer: 40 (2549, 7360) answers door
# [ 3] 19:07:37.7 Customer: 40 (2549, 7360) accepts Parcel:  76 ( 40)
# [ 3] 19:07:37.8 Customer: 40 (2549, 7360) signs off
# [ 3] 19:07:38.2 Driver drives to Customer: 61 (2880, 6075)
# [ 3] 19:14:06.0 Driver arrived at Customer: 61 (2880, 6075)
# [ 3] 19:14:44.8 Customer: 61 (2880, 6075) answers door
# [ 3] 19:14:44.8 Customer: 61 (2880, 6075) accepts Parcel:  77 ( 61)
# [ 3] 19:16:05.5 Customer: 61 (2880, 6075) signs off
# [ 3] 19:16:26.1 Driver drives to Customer: 19 (1760, 5886)
# [ 3] 19:22:59.5 Driver arrived at Customer: 19 (1760, 5886)
# [ 3] 19:23:47.6 Customer: 19 (1760, 5886) answers door
# [ 3] 19:23:47.6 Customer: 19 (1760, 5886) accepts Parcel:  73 ( 19)
# [ 3] 19:24:00.6 Customer: 19 (1760, 5886) signs off
# [ 3] 19:24:03.1 Driver drives to Customer: 14 (1490, 5120)
# [ 3] 19:28:11.8 Driver arrived at Customer: 14 (1490, 5120)
# [ 3] 19:29:07.5 Customer: 14 (1490, 5120) answers door
# [ 3] 19:29:07.5 Customer: 14 (1490, 5120) accepts Parcel:  72 ( 14)
# [ 3] 19:29:10.9 Customer: 14 (1490, 5120) signs off
# [ 3] 19:29:12.0 Driver drives to Customer:  3 (640, 4336)
# [ 3] 19:35:44.2 Driver arrived at Customer:  3 (640, 4336)
# [ 3] 19:36:08.9 Customer:  3 (640, 4336) answers door
# [ 3] 19:36:08.9 Customer:  3 (640, 4336) accepts Parcel:  69 (  3)
# [ 3] 19:36:12.9 Customer:  3 (640, 4336) signs off
# [ 3] 19:36:14.7 Driver drives to Customer:  2 (640, 4216)
# [ 3] 19:36:43.5 Driver arrived at Customer:  2 (640, 4216)
# [ 3] 19:37:05.4 Customer:  2 (640, 4216) answers door
# [ 3] 19:37:05.4 Customer:  2 (640, 4216) accepts Parcel:  68 (  2)
# [ 3] 19:37:28.2 Customer:  2 (640, 4216) signs off
# [ 3] 19:37:33.9 Driver drives to Customer:  4 (752, 2992)
# [ 3] 19:45:26.5 Driver arrived at Customer:  4 (752, 2992)
# [ 3] 19:45:50.2 Customer:  4 (752, 2992) answers door
# [ 3] 19:45:50.2 Customer:  4 (752, 2992) accepts Parcel:  70 (  4)
# [ 3] 19:46:02.5 Customer:  4 (752, 2992) signs off
# [ 3] 19:46:09.9 Driver drives to Customer: 13 (1466, 4000)
# [ 3] 19:52:00.1 Driver arrived at Customer: 13 (1466, 4000)
# [ 3] 19:52:05.6 Customer: 13 (1466, 4000) answers door
# [ 3] 19:52:05.6 Customer: 13 (1466, 4000) accepts Parcel:  71 ( 13)
# [ 3] 19:52:29.8 Customer: 13 (1466, 4000) signs off
# [ 3] 19:52:35.6 Driver drives to Customer: 30 (2320, 2669)
# [ 3] 20:01:20.0 Driver arrived at Customer: 30 (2320, 2669)
# [ 3] 20:02:22.3 Customer: 30 (2320, 2669) answers door
# [ 3] 20:02:22.3 Customer: 30 (2320, 2669) accepts Parcel:  75 ( 30)
# [ 3] 20:02:27.3 Customer: 30 (2320, 2669) signs off
# [ 3] 20:02:43.7 Driver drives to Customer: 24 (2010, 2320)
# [ 3] 20:05:21.9 Driver arrived at Customer: 24 (2010, 2320)
# [ 3] 20:05:41.6 Customer: 24 (2010, 2320) answers door
# [ 3] 20:05:41.6 Customer: 24 (2010, 2320) accepts Parcel:  74 ( 24)
# [ 3] 20:05:44.1 Customer: 24 (2010, 2320) signs off
# [ 3] 20:05:46.3 Driver drives to Customer: 67 (3255, 640)
# [ 3] 20:17:28.3 Driver arrived at Customer: 67 (3255, 640)
# [ 3] 20:19:20.8 Customer: 67 (3255, 640) answers door
# [ 3] 20:19:20.8 Customer: 67 (3255, 640) accepts Parcel:  78 ( 67)
# [ 3] 20:19:29.7 Customer: 67 (3255, 640) signs off
# [ 3] 20:19:30.2 Driver drives to Customer: 72 (3632, 2127)
# [ 3] 20:31:03.1 Driver arrived at Customer: 72 (3632, 2127)
# [ 3] 20:31:22.7 Customer: 72 (3632, 2127) answers door
# [ 3] 20:31:22.7 Customer: 72 (3632, 2127) accepts Parcel:  79 ( 72)
# [ 3] 20:31:25.4 Customer: 72 (3632, 2127) accepts Parcel:  80 ( 72)
# [ 3] 20:31:26.3 Customer: 72 (3632, 2127) signs off
# [ 3] 20:31:28.3 Driver drives to Customer: 94 (4739, 1760)
# [ 3] 20:36:30.3 Driver arrived at Customer: 94 (4739, 1760)
# [ 3] 20:36:32.6 Customer: 94 (4739, 1760) answers door
# [ 3] 20:36:32.6 Customer: 94 (4739, 1760) accepts Parcel:  82 ( 94)
# [ 3] 20:36:42.8 Customer: 94 (4739, 1760) signs off
# [ 3] 20:36:44.7 Driver drives to Customer: 96 (4757, 2880)
# [ 3] 20:42:43.7 Driver arrived at Customer: 96 (4757, 2880)
# [ 3] 20:43:21.5 Customer: 96 (4757, 2880) answers door
# [ 3] 20:43:21.5 Customer: 96 (4757, 2880) accepts Parcel:  84 ( 96)
# [ 3] 20:43:30.9 Customer: 96 (4757, 2880) signs off
# [ 3] 20:43:43.1 Driver returns to delivery centre
# [ 3] 20:48:59.2 Driver arrived at delivery centre
# [ 3] 20:58:59.2 3 left over for next day
# [ 3] 20:58:59.2 Driver goes home
# [ 4] 08:35:52.9 Parcel:  90 (  3) arr at delivery centre
# [ 4] 08:46:17.0 Parcel:  91 ( 11) arr at delivery centre
# [ 4] 08:53:28.2 Parcel:  92 ( 11) arr at delivery centre
# [ 4] 09:06:25.5 Parcel:  93 ( 13) arr at delivery centre
# [ 4] 10:13:28.9 Parcel:  94 ( 16) arr at delivery centre
# [ 4] 10:43:20.4 Parcel:  95 ( 18) arr at delivery centre
# [ 4] 11:02:15.6 Parcel:  96 ( 24) arr at delivery centre
# [ 4] 11:03:17.5 Parcel:  97 ( 25) arr at delivery centre
# [ 4] 11:14:40.6 Parcel:  98 ( 31) arr at delivery centre
# [ 4] 11:22:40.4 Parcel:  99 ( 32) arr at delivery centre
# [ 4] 11:34:36.5 Parcel: 100 ( 35) arr at delivery centre
# [ 4] 11:56:59.2 Parcel: 101 ( 40) arr at delivery centre
# [ 4] 12:00:19.7 Parcel: 102 ( 41) arr at delivery centre
# [ 4] 12:16:06.4 Parcel: 103 ( 43) arr at delivery centre
# [ 4] 12:17:36.1 Parcel: 104 ( 44) arr at delivery centre
# [ 4] 12:20:35.4 Parcel: 105 ( 67) arr at delivery centre
# [ 4] 12:39:35.0 Parcel: 106 ( 70) arr at delivery centre
# [ 4] 12:44:26.0 Parcel: 107 ( 71) arr at delivery centre
# [ 4] 13:04:44.5 Parcel: 108 ( 75) arr at delivery centre
# [ 4] 13:06:00.8 Parcel: 109 ( 79) arr at delivery centre
# [ 4] 13:07:54.7 Parcel: 110 ( 83) arr at delivery centre
# [ 4] 13:22:16.0 Parcel: 111 ( 93) arr at delivery centre
# [ 4] 13:22:49.3 Parcel: 112 (104) arr at delivery centre
# [ 4] 13:33:03.5 Parcel: 113 (104) arr at delivery centre
# [ 4] 14:01:57.3 Parcel: 114 (109) arr at delivery centre
# [ 4] 14:11:07.4 Parcel: 115 (110) arr at delivery centre
# [ 4] 14:24:49.1 Parcel: 116 (111) arr at delivery centre
# [ 4] 14:25:08.6 Parcel: 117 (117) arr at delivery centre
# [ 4] 14:37:14.3 Parcel: 118 (118) arr at delivery centre
# [ 4] 14:48:25.5 Parcel: 119 (118) arr at delivery centre
# [ 4] 14:58:43.2 Parcel: 120 (121) arr at delivery centre
# [ 4] 15:04:40.5 Parcel: 121 (121) arr at delivery centre
# [ 4] 15:10:13.3 Parcel: 122 (125) arr at delivery centre
# [ 4] 15:57:28.8 Parcel: 123 (129) arr at delivery centre
# [ 4] 15:57:55.5 Parcel: 124 (149) arr at delivery centre
# [ 4] 18:00:00.0 Driver arrives for work
# [ 4] 18:00:00.0 Parcel: 109 ( 79) out for delivery
# [ 4] 18:00:00.0 Parcel:  86 (112) out for delivery
# [ 4] 18:00:00.0 Parcel: 123 (129) out for delivery
# [ 4] 18:00:00.0 Parcel:  88 (125) out for delivery
# [ 4] 18:00:00.0 Parcel: 122 (125) out for delivery
# [ 4] 18:00:00.0 Parcel:  89 (139) out for delivery
# [ 4] 18:00:00.0 Parcel: 115 (110) out for delivery
# [ 4] 18:00:00.0 Parcel: 111 ( 93) out for delivery
# [ 4] 18:00:00.0 Parcel: 101 ( 40) out for delivery
# [ 4] 18:00:00.0 Parcel: 100 ( 35) out for delivery
# [ 4] 18:00:00.0 Parcel: 106 ( 70) out for delivery
# [ 4] 18:00:00.0 Parcel: 107 ( 71) out for delivery
# [ 4] 18:00:00.0 Parcel:  95 ( 18) out for delivery
# [ 4] 18:00:00.0 Parcel:  91 ( 11) out for delivery
# [ 4] 18:00:00.0 Parcel:  92 ( 11) out for delivery
# [ 4] 18:00:00.0 Parcel:  90 (  3) out for delivery
# [ 4] 18:00:00.0 Parcel:  93 ( 13) out for delivery
# [ 4] 18:00:00.0 Parcel:  94 ( 16) out for delivery
# [ 4] 18:00:00.0 Parcel:  97 ( 25) out for delivery
# [ 4] 18:00:00.0 Parcel:  99 ( 32) out for delivery
# [ 4] 18:00:00.0 Parcel: 103 ( 43) out for delivery
# [ 4] 18:00:00.0 Parcel: 104 ( 44) out for delivery
# [ 4] 18:00:00.0 Parcel:  96 ( 24) out for delivery
# [ 4] 18:00:00.0 Parcel:  98 ( 31) out for delivery
# [ 4] 18:00:00.0 Parcel: 102 ( 41) out for delivery
# [ 4] 18:00:00.0 Parcel: 108 ( 75) out for delivery
# [ 4] 18:21:40.0 Driver leaves for delivery of 26 parcels
# [ 4] 18:21:40.0 Driver drives to Customer: 79 (4000, 3110)
# [ 4] 18:22:59.2 Driver arrived at Customer: 79 (4000, 3110)
# [ 4] 18:23:27.9 Customer: 79 (4000, 3110) answers door
# [ 4] 18:23:27.9 Customer: 79 (4000, 3110) accepts Parcel: 109 ( 79)
# [ 4] 18:23:31.2 Customer: 79 (4000, 3110) signs off
# [ 4] 18:23:52.2 Driver drives to Customer: 112 (5489, 830)
# [ 4] 18:38:04.7 Driver arrived at Customer: 112 (5489, 830)
# [ 4] 18:38:22.1 Customer: 112 (5489, 830) answers door
# [ 4] 18:38:22.1 Customer: 112 (5489, 830) accepts Parcel:  86 (112)
# [ 4] 18:38:28.2 Customer: 112 (5489, 830) signs off
# [ 4] 18:38:38.2 Driver drives to Customer: 129 (6510, 2880)
# [ 4] 18:53:00.3 Driver arrived at Customer: 129 (6510, 2880)
# [ 4] 18:53:29.3 Customer: 129 (6510, 2880) answers door
# [ 4] 18:53:29.3 Customer: 129 (6510, 2880) accepts Parcel: 123 (129)
# [ 4] 18:54:00.7 Customer: 129 (6510, 2880) signs off
# [ 4] 19:57:16.6 Customer: 71 (3619, 5120) signs off
# [ 4] 19:57:20.5 Driver drives to Customer: 18 (1760, 5565)
# [ 4] 20:06:33.5 Driver arrived at Customer: 18 (1760, 5565)
# [ 4] 20:06:34.7 Customer: 18 (1760, 5565) answers door
# [ 4] 20:06:34.7 Customer: 18 (1760, 5565) accepts Parcel:  95 ( 18)
# [ 4] 20:06:35.1 Customer: 18 (1760, 5565) signs off
# [ 4] 20:06:39.7 Driver drives to Customer: 11 (1200, 4797)
# [ 4] 20:11:58.4 Driver arrived at Customer: 11 (1200, 4797)
# [ 4] 20:12:07.8 Customer: 11 (1200, 4797) answers door
# [ 4] 20:12:07.8 Customer: 11 (1200, 4797) accepts Parcel:  91 ( 11)
# [ 4] 20:12:15.3 Customer: 11 (1200, 4797) accepts Parcel:  92 ( 11)
# [ 4] 20:12:17.4 Customer: 11 (1200, 4797) signs off
# [ 4] 20:12:19.6 Driver drives to Customer:  3 (640, 4336)
# [ 4] 20:16:24.7 Driver arrived at Customer:  3 (640, 4336)
# [ 4] 20:17:09.3 Customer:  3 (640, 4336) answers door
# [ 4] 20:17:09.3 Customer:  3 (640, 4336) accepts Parcel:  90 (  3)
# [ 4] 20:17:22.6 Customer:  3 (640, 4336) signs off
# [ 4] 20:17:26.4 Driver drives to Customer: 13 (1466, 4000)
# [ 4] 20:22:05.3 Driver arrived at Customer: 13 (1466, 4000)
# [ 4] 20:23:23.9 Customer: 13 (1466, 4000) answers door
# [ 4] 20:23:23.9 Customer: 13 (1466, 4000) accepts Parcel:  93 ( 13)
# [ 4] 20:23:26.8 Customer: 13 (1466, 4000) signs off
# [ 4] 20:23:31.0 Driver drives to Customer: 16 (1760, 4226)
# [ 4] 20:25:35.8 Driver arrived at Customer: 16 (1760, 4226)
# [ 4] 20:26:25.7 Customer: 16 (1760, 4226) answers door
# [ 4] 20:26:25.7 Customer: 16 (1760, 4226) accepts Parcel:  94 ( 16)
# [ 4] 20:26:26.2 Customer: 16 (1760, 4226) signs off
# [ 4] 20:26:53.4 Driver drives to Customer: 25 (2030, 4000)
# [ 4] 20:28:52.4 Driver arrived at Customer: 25 (2030, 4000)
# [ 4] 20:28:55.4 Customer: 25 (2030, 4000) answers door
# [ 4] 20:28:55.4 Customer: 25 (2030, 4000) accepts Parcel:  97 ( 25)
# [ 4] 20:29:01.6 Customer: 25 (2030, 4000) signs off
# [ 4] 20:29:14.5 Driver drives to Customer: 32 (2320, 4217)
# [ 4] 20:31:16.2 Driver arrived at Customer: 32 (2320, 4217)
# [ 4] 20:31:18.1 Customer: 32 (2320, 4217) answers door
# [ 4] 20:31:18.1 Customer: 32 (2320, 4217) accepts Parcel:  99 ( 32)
# [ 4] 20:31:34.7 Customer: 32 (2320, 4217) signs off
# [ 4] 20:32:13.3 Driver drives to Customer: 43 (2659, 4000)
# [ 4] 20:34:26.7 Driver arrived at Customer: 43 (2659, 4000)
# [ 4] 20:34:51.4 Customer: 43 (2659, 4000) answers door
# [ 4] 20:34:51.4 Customer: 43 (2659, 4000) accepts Parcel: 103 ( 43)
# [ 4] 20:34:52.6 Customer: 43 (2659, 4000) signs off
# [ 4] 20:34:53.5 Driver drives to Customer: 44 (2684, 2880)
# [ 4] 20:41:02.4 Driver arrived at Customer: 44 (2684, 2880)
# [ 4] 20:41:06.5 Customer: 44 (2684, 2880) answers door
# [ 4] 20:41:06.5 Customer: 44 (2684, 2880) accepts Parcel: 104 ( 44)
# [ 4] 20:41:21.0 Customer: 44 (2684, 2880) signs off
# [ 4] 20:41:26.4 Driver drives to Customer: 24 (2010, 2320)
# [ 4] 20:46:22.5 Driver arrived at Customer: 24 (2010, 2320)
# [ 4] 20:48:03.2 Customer: 24 (2010, 2320) answers door
# [ 4] 20:48:03.2 Customer: 24 (2010, 2320) accepts Parcel:  96 ( 24)
# [ 4] 20:48:09.0 Customer: 24 (2010, 2320) signs off
# [ 4] 20:48:09.8 Driver drives to Customer: 31 (2320, 3207)
# [ 4] 20:52:57.1 Driver arrived at Customer: 31 (2320, 3207)
# [ 4] 20:53:19.3 Customer: 31 (2320, 3207) answers door
# [ 4] 20:53:19.3 Customer: 31 (2320, 3207) accepts Parcel:  98 ( 31)
# [ 4] 20:53:33.4 Customer: 31 (2320, 3207) signs off
# [ 4] 20:53:51.1 Driver drives to Customer: 41 (2574, 3440)
# ...
# [18] 18:31:09.4 Driver arrived at Customer: 66 (3229, 2880)
# [18] 18:32:55.5 Customer: 66 (3229, 2880) answers door
# [18] 18:32:55.5 Customer: 66 (3229, 2880) accepts Parcel: 415 ( 66)
# [18] 18:33:30.2 Customer: 66 (3229, 2880) accepts Parcel: 416 ( 66)
# [18] 18:33:37.6 Customer: 66 (3229, 2880) signs off
# [18] 18:33:38.5 Driver drives to Customer: 78 (3914, 1845)
# [18] 18:39:24.6 Driver arrived at Customer: 78 (3914, 1845)
# [18] 18:39:38.8 Customer: 78 (3914, 1845) answers door
# [18] 18:39:38.8 Customer: 78 (3914, 1845) accepts Parcel: 418 ( 78)
# [18] 18:39:46.1 Customer: 78 (3914, 1845) signs off
# [18] 18:39:57.3 Driver drives to Customer: 112 (5489, 830)
# [18] 18:49:14.6 Driver arrived at Customer: 112 (5489, 830)
# [18] 18:51:11.5 Customer: 112 (5489, 830) answers door
# [18] 18:51:11.5 Customer: 112 (5489, 830) accepts Parcel: 425 (112)
# [18] 18:51:13.2 Customer: 112 (5489, 830) signs off
# [18] 18:51:13.6 Driver drives to Customer: 114 (5680, 2188)
# [18] 18:59:30.4 Driver arrived at Customer: 114 (5680, 2188)
# [18] 19:00:52.0 Customer: 114 (5680, 2188) answers door
# [18] 19:00:52.0 Customer: 114 (5680, 2188) accepts Parcel: 426 (114)
# [18] 19:01:08.3 Customer: 114 (5680, 2188) accepts Parcel: 427 (114)
# [18] 19:01:22.8 Customer: 114 (5680, 2188) signs off
# [18] 19:01:29.2 Driver drives to Customer: 109 (5414, 2880)
# [18] 19:05:19.1 Driver arrived at Customer: 109 (5414, 2880)
# [19] 19:33:19.9 Driver arrived at Customer: 77 (3831, 7360)
# [19] 19:33:42.6 Customer: 77 (3831, 7360) answers door
# [19] 19:33:42.6 Customer: 77 (3831, 7360) accepts Parcel: 439 ( 77)
# [19] 19:33:53.6 Customer: 77 (3831, 7360) signs off
# [19] 19:34:26.3 Driver drives to Customer: 35 (2320, 6492)
# [19] 19:43:57.3 Driver arrived at Customer: 35 (2320, 6492)
# [19] 19:44:54.6 Customer: 35 (2320, 6492) answers door
# [19] 19:44:54.6 Customer: 35 (2320, 6492) accepts Parcel: 436 ( 35)
# [19] 19:45:16.3 Customer: 35 (2320, 6492) signs off
# [19] 19:45:17.5 Driver drives to Customer: 21 (1871, 4560)
# [19] 19:55:42.2 Driver arrived at Customer: 21 (1871, 4560)
# [19] 19:56:04.7 Customer: 21 (1871, 4560) answers door
# [19] 19:56:04.7 Customer: 21 (1871, 4560) accepts Parcel: 434 ( 21)
# [19] 19:56:05.0 Customer: 21 (1871, 4560) signs off
# [19] 19:56:08.2 Driver drives to Customer: 25 (2030, 4000)
# [19] 19:59:54.0 Driver arrived at Customer: 25 (2030, 4000)
# [19] 20:00:13.4 Customer: 25 (2030, 4000) answers door
# [19] 20:00:13.4 Customer: 25 (2030, 4000) accepts Parcel: 435 ( 25)
# [19] 20:00:17.7 Customer: 25 (2030, 4000) signs off
# [19] 20:00:22.3 Driver drives to Customer: 92 (4377, 4742)
# [19] 20:14:51.9 Driver arrived at Customer: 92 (4377, 4742)
# [19] 20:15:56.9 Customer: 92 (4377, 4742) answers door
# [19] 20:15:56.9 Customer: 92 (4377, 4742) accepts Parcel: 441 ( 92)
# [19] 20:15:59.0 Customer: 92 (4377, 4742) signs off
# [19] 20:16:16.4 Driver drives to Customer: 101 (4949, 4560)
# [19] 20:18:51.6 Driver arrived at Customer: 101 (4949, 4560)
# [19] 20:19:22.9 Customer: 101 (4949, 4560) answers door
# [19] 20:19:22.9 Customer: 101 (4949, 4560) accepts Parcel: 443 (101)
# [19] 20:19:27.0 Customer: 101 (4949, 4560) signs off
# [19] 20:19:35.0 Driver returns to delivery centre
# [19] 20:29:13.7 Driver arrived at delivery centre
# [19] 20:39:13.7 0 left over for next day
# [19] 20:39:13.7 Driver goes home
# Delivery Centre Inventory: 0 parcels

# %%
with open('rec.pickle', 'rb') as f:
    rec1 = pickle.load(f)

# %%
rec1.histWorkingTime()
rec1.plotWorkingTime()
rec1.statsWorkingTime()
# Out:
# (183.4, 186.5, 14.368825905227498)

# %%
rec1.histTourLength()
rec1.plotTourLength()
rec1.statsTourLength()
# Out:
# (33475.0, 34255.5, 1949.5782809839184)

# %%
rec1.histLeftOver()
rec1.plotLeftOver()
rec1.statsLeftOver()
# Out:
# (2.65, 0.5, 3.5876249290552864)

# %%
rec1.reportTimer()
# Out:
# ==== t: 2637.12s Total
# ==== ΣΔt: 2569.22s createLoop
# ==== ΣΔt:  66.71s createLoopH
# ==== ΣΔt:   1.19s addTarget

# %% [markdown]
# ## For finding optimal warehouse location

# %%
def generateWarehouseLocations(M, seed=None):
    if seed is not None:
        random.seed(seed)
    V, _ = M
    W = random.sample(V, k=len(V)//10)
    return W

# %%
random.seed(0)
W = generateWarehouseLocations(M, seed=9340)
print("Warehouse locations:", W)

records = []

for i in range(len(W)):
    rec = simulation(M, W[i], C, p=0.15, days=7, log=True)
    records.append(rec)

with open(f'records.pickle', 'wb') as f:
    pickle.dump(records, f)
# Out:
# Warehouse locations: [(6240, 1760), (1760, 5120), (5120, 4560), (4000, 5680), (2880, 2880), (5680, 2880), (4000, 7360), (4560, 4560), (2320, 640), (7360, 4000)]
# generating for day:  0 [9, 9, 28, 29, 31, 32, 32, 34, 53, 72, 77, 79, 82, 99, 114, 115, 127, 128, 128, 142, 147, 147, 148]
# generating for day:  1 [1, 11, 17, 31, 35, 38, 42, 53, 57, 65, 79, 82, 91, 99, 102, 105, 119, 120, 121, 128, 132, 133, 140, 142]
# generating for day:  2 [0, 6, 23, 47, 48, 49, 68, 69, 78, 84, 85, 94, 95, 100, 113, 117, 127, 131, 141, 143, 148]
# generating for day:  3 [0, 23, 36, 42, 43, 48, 62, 82, 93, 98, 98, 112, 114, 121, 123, 127, 127, 130, 131, 138, 148, 149]
# generating for day:  4 [2, 2, 3, 10, 11, 13, 14, 19, 19, 24, 30, 32, 36, 38, 40, 41, 42, 43, 50, 51, 58, 67, 72, 72, 77, 80, 86, 94, 95, 104, 107, 112, 115, 125, 128]
# generating for day:  5 [4, 13, 14, 16, 18, 25, 31, 40, 41, 61, 70, 71, 75, 79, 83, 86, 96, 104, 109, 110, 117, 118, 121, 121, 121, 139, 149]
# generating for day:  6 [2, 3, 11, 11, 24, 27, 32, 35, 43, 44, 51, 53, 67, 93, 104, 111, 111, 118, 125, 125, 129, 138, 148]
# Simulating delivery of 175 parcels over 7 days to 150 customers
# [ 0] 08:33:58.5 Parcel:   0 (  9) arr at delivery centre
# [ 0] 08:59:52.8 Parcel:   1 (  9) arr at delivery centre
# [ 0] 09:09:50.7 Parcel:   2 ( 28) arr at delivery centre
# [ 0] 09:15:19.0 Parcel:   3 ( 29) arr at delivery centre
# [ 0] 09:28:23.5 Parcel:   4 ( 31) arr at delivery centre
# [ 0] 09:37:52.1 Parcel:   5 ( 32) arr at delivery centre
# [ 0] 10:05:50.1 Parcel:   6 ( 32) arr at delivery centre
# [ 0] 10:12:26.1 Parcel:   7 ( 34) arr at delivery centre
# [ 0] 10:24:15.5 Parcel:   8 ( 53) arr at delivery centre
# [ 0] 10:40:14.8 Parcel:   9 ( 72) arr at delivery centre
# [ 0] 11:23:50.3 Parcel:  10 ( 77) arr at delivery centre
# [ 0] 11:36:40.1 Parcel:  11 ( 79) arr at delivery centre
# [ 0] 11:42:42.8 Parcel:  12 ( 82) arr at delivery centre
# [ 0] 12:08:27.4 Parcel:  13 ( 99) arr at delivery centre
# [ 0] 12:26:02.8 Parcel:  14 (114) arr at delivery centre
# [ 0] 12:31:18.7 Parcel:  15 (115) arr at delivery centre
# [ 0] 13:15:13.9 Parcel:  16 (127) arr at delivery centre
# [ 0] 14:29:24.4 Parcel:  17 (128) arr at delivery centre
# [ 0] 14:59:45.2 Parcel:  18 (128) arr at delivery centre
# [ 0] 15:42:12.0 Parcel:  19 (142) arr at delivery centre
# [ 0] 15:48:58.8 Parcel:  20 (147) arr at delivery centre
# [ 0] 16:12:52.7 Parcel:  21 (147) arr at delivery centre
# [ 0] 16:54:42.9 Parcel:  22 (148) arr at delivery centre
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel:  13 ( 99) out for delivery
# [ 0] 18:00:00.0 Parcel:  11 ( 79) out for delivery
# [ 0] 18:00:00.0 Parcel:   9 ( 72) out for delivery
# [ 0] 18:00:00.0 Parcel:   8 ( 53) out for delivery
# [ 0] 18:00:00.0 Parcel:   3 ( 29) out for delivery
# [ 0] 18:00:00.0 Parcel:   4 ( 31) out for delivery
# [ 0] 18:00:00.0 Parcel:   0 (  9) out for delivery
# [ 0] 18:00:00.0 Parcel:   1 (  9) out for delivery
# [ 0] 18:00:00.0 Parcel:   5 ( 32) out for delivery
# [ 0] 18:00:00.0 Parcel:   6 ( 32) out for delivery
# [ 0] 18:00:00.0 Parcel:   7 ( 34) out for delivery
# [ 0] 18:00:00.0 Parcel:   2 ( 28) out for delivery
# [ 0] 18:00:00.0 Parcel:  10 ( 77) out for delivery
# [ 0] 18:00:00.0 Parcel:  12 ( 82) out for delivery
# [ 0] 18:00:00.0 Parcel:  19 (142) out for delivery
# [ 0] 18:00:00.0 Parcel:  16 (127) out for delivery
# [ 0] 18:00:00.0 Parcel:  22 (148) out for delivery
# [ 0] 18:00:00.0 Parcel:  20 (147) out for delivery
# [ 0] 18:00:00.0 Parcel:  21 (147) out for delivery
# [ 0] 18:00:00.0 Parcel:  17 (128) out for delivery
# [ 0] 18:00:00.0 Parcel:  18 (128) out for delivery
# [ 0] 18:00:00.0 Parcel:  15 (115) out for delivery
# [ 0] 18:00:00.0 Parcel:  14 (114) out for delivery
# [ 0] 18:19:10.0 Driver leaves for delivery of 23 parcels
# [ 0] 18:19:10.0 Driver drives to Customer: 99 (4860, 940)
# [ 0] 18:27:21.2 Driver arrived at Customer: 99 (4860, 940)
# [ 0] 18:29:23.6 Customer: 99 (4860, 940) answers door
# [ 0] 18:29:23.6 Customer: 99 (4860, 940) accepts Parcel:  13 ( 99)
# [ 0] 18:29:28.0 Customer: 99 (4860, 940) signs off
# [ 0] 18:29:31.4 Driver drives to Customer: 79 (4000, 3110)
# [ 0] 18:43:06.7 Driver arrived at Customer: 79 (4000, 3110)
# [ 0] 18:43:24.5 Customer: 79 (4000, 3110) answers door
# [ 0] 18:43:24.5 Customer: 79 (4000, 3110) accepts Parcel:  11 ( 79)
# [ 0] 18:43:53.8 Customer: 79 (4000, 3110) signs off
# [ 0] 18:44:03.9 Driver drives to Customer: 72 (3632, 2127)
# [ 0] 18:50:33.1 Driver arrived at Customer: 72 (3632, 2127)
# [ 0] 18:51:12.0 Customer: 72 (3632, 2127) answers door
# [ 0] 18:51:12.0 Customer: 72 (3632, 2127) accepts Parcel:   9 ( 72)
# [ 0] 18:51:24.5 Customer: 72 (3632, 2127) signs off
# [ 0] 18:51:29.4 Driver drives to Customer: 53 (2880, 2004)
# [ 0] 18:56:05.0 Driver arrived at Customer: 53 (2880, 2004)
# [ 0] 18:56:26.4 Customer: 53 (2880, 2004) answers door
# [ 0] 18:56:26.4 Customer: 53 (2880, 2004) accepts Parcel:   8 ( 53)
# [ 0] 18:56:36.9 Customer: 53 (2880, 2004) signs off
# [ 0] 18:56:36.9 Driver drives to Customer: 29 (2320, 2503)
# [ 0] 19:00:51.1 Driver arrived at Customer: 29 (2320, 2503)
# [ 0] 19:00:59.6 Customer: 29 (2320, 2503) answers door
# [ 0] 19:00:59.6 Customer: 29 (2320, 2503) accepts Parcel:   3 ( 29)
# [ 0] 19:01:03.7 Customer: 29 (2320, 2503) signs off
# [ 0] 19:01:06.4 Driver drives to Customer: 31 (2320, 3207)
# [ 0] 19:03:55.4 Driver arrived at Customer: 31 (2320, 3207)
# [ 0] 19:04:36.0 Customer: 31 (2320, 3207) answers door
# [ 0] 19:04:36.0 Customer: 31 (2320, 3207) accepts Parcel:   4 ( 31)
# [ 0] 19:04:40.7 Customer: 31 (2320, 3207) signs off
# [ 0] 19:05:01.5 Driver drives to Customer:  9 (1200, 3695)
# [ 0] 19:13:53.9 Driver arrived at Customer:  9 (1200, 3695)
# [ 0] 19:14:27.5 Customer:  9 (1200, 3695) answers door
# [ 0] 19:14:27.5 Customer:  9 (1200, 3695) accepts Parcel:   0 (  9)
# [ 0] 19:14:32.8 Customer:  9 (1200, 3695) accepts Parcel:   1 (  9)
# [ 0] 19:14:37.9 Customer:  9 (1200, 3695) signs off
# [ 0] 19:14:50.1 Driver drives to Customer: 32 (2320, 4217)
# [ 0] 19:21:24.1 Driver arrived at Customer: 32 (2320, 4217)
# [ 0] 19:21:45.8 Customer: 32 (2320, 4217) answers door
# [ 0] 19:21:45.8 Customer: 32 (2320, 4217) accepts Parcel:   5 ( 32)
# [ 0] 19:21:56.7 Customer: 32 (2320, 4217) accepts Parcel:   6 ( 32)
# [ 0] 19:21:57.1 Customer: 32 (2320, 4217) signs off
# [ 0] 19:22:03.0 Driver drives to Customer: 34 (2320, 4756)
# [ 0] 19:24:12.4 Driver arrived at Customer: 34 (2320, 4756)
# [ 0] 19:24:24.4 Customer: 34 (2320, 4756) answers door
# [ 0] 19:24:24.4 Customer: 34 (2320, 4756) accepts Parcel:   7 ( 34)
# [ 0] 19:24:26.1 Customer: 34 (2320, 4756) signs off
# [ 0] 19:24:33.6 Driver drives to Customer: 28 (2217, 6240)
# [ 0] 19:34:33.8 Driver arrived at Customer: 28 (2217, 6240)
# [ 0] 19:35:00.6 Customer: 28 (2217, 6240) answers door
# [ 0] 19:35:00.6 Customer: 28 (2217, 6240) accepts Parcel:   2 ( 28)
# [ 0] 19:35:08.8 Customer: 28 (2217, 6240) signs off
# [ 0] 20:46:26.3 Customer: 115 (5680, 2523) accepts Parcel:  15 (115)
# [ 0] 20:46:47.0 Customer: 115 (5680, 2523) signs off
# [ 0] 20:46:50.3 Driver drives to Customer: 114 (5680, 2188)
# [ 0] 20:48:10.7 Driver arrived at Customer: 114 (5680, 2188)
# [ 0] 20:50:44.3 Customer: 114 (5680, 2188) answers door
# [ 0] 20:50:44.3 Customer: 114 (5680, 2188) accepts Parcel:  14 (114)
# [ 0] 20:50:45.4 Customer: 114 (5680, 2188) signs off
# [ 0] 20:51:04.6 Driver returns to delivery centre
# [ 0] 20:55:01.7 Driver arrived at delivery centre
# [ 0] 21:05:01.7 0 left over for next day
# [ 0] 21:05:01.7 Driver goes home
# [ 1] 08:20:09.2 Parcel:  23 (  1) arr at delivery centre
# [ 1] 08:31:20.1 Parcel:  24 ( 11) arr at delivery centre
# [ 1] 08:33:11.5 Parcel:  25 ( 17) arr at delivery centre
# [ 1] 08:43:09.3 Parcel:  26 ( 31) arr at delivery centre
# [ 1] 08:59:40.5 Parcel:  27 ( 35) arr at delivery centre
# [ 1] 09:42:24.6 Parcel:  28 ( 38) arr at delivery centre
# [ 1] 10:41:54.0 Parcel:  29 ( 42) arr at delivery centre
# [ 1] 10:53:14.6 Parcel:  30 ( 53) arr at delivery centre
# [ 1] 11:28:19.6 Parcel:  31 ( 57) arr at delivery centre
# [ 1] 11:33:36.5 Parcel:  32 ( 65) arr at delivery centre
# [ 1] 12:02:13.1 Parcel:  33 ( 79) arr at delivery centre
# [ 1] 12:16:08.5 Parcel:  34 ( 82) arr at delivery centre
# [ 1] 12:16:23.3 Parcel:  35 ( 91) arr at delivery centre
# [ 1] 12:38:38.7 Parcel:  36 ( 99) arr at delivery centre
# [ 1] 12:47:33.0 Parcel:  37 (102) arr at delivery centre
# [ 1] 13:18:02.2 Parcel:  38 (105) arr at delivery centre
# [ 1] 13:37:20.5 Parcel:  39 (119) arr at delivery centre
# [ 1] 13:37:21.7 Parcel:  40 (120) arr at delivery centre
# [ 1] 13:49:16.1 Parcel:  41 (121) arr at delivery centre
# [ 1] 14:24:39.1 Parcel:  42 (128) arr at delivery centre
# [ 1] 14:29:32.7 Parcel:  43 (132) arr at delivery centre
# [ 1] 14:36:25.7 Parcel:  44 (133) arr at delivery centre
# [ 1] 15:12:11.7 Parcel:  45 (140) arr at delivery centre
# [ 1] 15:15:54.3 Parcel:  46 (142) arr at delivery centre
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel:  44 (133) out for delivery
# [ 1] 18:00:00.0 Parcel:  42 (128) out for delivery
# [ 1] 18:00:00.0 Parcel:  39 (119) out for delivery
# [ 1] 18:00:00.0 Parcel:  33 ( 79) out for delivery
# [ 1] 18:00:00.0 Parcel:  31 ( 57) out for delivery
# [ 1] 18:00:00.0 Parcel:  32 ( 65) out for delivery
# [ 1] 18:00:00.0 Parcel:  34 ( 82) out for delivery
# [ 1] 18:00:00.0 Parcel:  29 ( 42) out for delivery
# [ 2] 20:36:21.2 Customer: 143 (7220, 4560) accepts Parcel:  66 (143)
# [ 2] 20:36:46.1 Customer: 143 (7220, 4560) signs off
# [ 2] 20:36:50.0 Driver drives to Customer: 140 (7031, 4560)
# [ 2] 20:37:35.3 Driver arrived at Customer: 140 (7031, 4560)
# [ 2] 20:38:02.9 Customer: 140 (7031, 4560) answers door
# [ 2] 20:38:02.9 Customer: 140 (7031, 4560) accepts Parcel:  45 (140)
# [ 2] 20:38:09.8 Customer: 140 (7031, 4560) signs off
# [ 2] 20:38:20.9 Driver drives to Customer: 127 (6425, 4560)
# [ 2] 20:40:46.4 Driver arrived at Customer: 127 (6425, 4560)
# [ 2] 20:40:55.4 Customer: 127 (6425, 4560) answers door
# [ 2] 20:40:55.4 Customer: 127 (6425, 4560) accepts Parcel:  63 (127)
# [ 2] 20:41:04.8 Customer: 127 (6425, 4560) signs off
# [ 2] 20:41:07.3 Driver drives to Customer: 131 (6587, 3440)
# [ 2] 20:47:57.2 Driver arrived at Customer: 131 (6587, 3440)
# [ 2] 20:48:13.8 Customer: 131 (6587, 3440) answers door
# [ 2] 20:48:13.8 Customer: 131 (6587, 3440) accepts Parcel:  64 (131)
# [ 2] 20:48:46.7 Customer: 131 (6587, 3440) signs off
# [ 2] 20:49:09.6 Driver drives to Customer: 113 (5680, 1965)
# [ 2] 20:58:41.3 Driver arrived at Customer: 113 (5680, 1965)
# [ 2] 20:59:49.5 Customer: 113 (5680, 1965) answers door
# [ 2] 20:59:49.5 Customer: 113 (5680, 1965) accepts Parcel:  61 (113)
# [ 2] 20:59:49.8 Customer: 113 (5680, 1965) signs off
# [ 2] 20:59:51.4 Driver returns to delivery centre
# [ 2] 21:02:55.0 Driver arrived at delivery centre
# [ 2] 21:12:55.0 3 left over for next day
# [ 2] 21:12:55.0 Driver goes home
# [ 3] 08:16:21.4 Parcel:  68 (  0) arr at delivery centre
# [ 3] 08:22:54.2 Parcel:  69 ( 23) arr at delivery centre
# [ 3] 08:26:54.7 Parcel:  70 ( 36) arr at delivery centre
# [ 3] 08:30:51.5 Parcel:  71 ( 42) arr at delivery centre
# [ 3] 08:48:58.2 Parcel:  72 ( 43) arr at delivery centre
# [ 3] 09:09:22.7 Parcel:  73 ( 48) arr at delivery centre
# [ 3] 09:21:44.1 Parcel:  74 ( 62) arr at delivery centre
# [ 3] 09:23:31.9 Parcel:  75 ( 82) arr at delivery centre
# [ 3] 09:50:35.2 Parcel:  76 ( 93) arr at delivery centre
# [ 3] 10:30:33.4 Parcel:  77 ( 98) arr at delivery centre
# [ 3] 11:19:36.0 Parcel:  78 ( 98) arr at delivery centre
# [ 3] 11:54:52.9 Parcel:  79 (112) arr at delivery centre
# [ 3] 12:38:29.7 Parcel:  80 (114) arr at delivery centre
# [ 3] 13:27:27.7 Parcel:  81 (121) arr at delivery centre
# [ 3] 13:42:18.7 Parcel:  82 (123) arr at delivery centre
# [ 3] 13:51:47.3 Parcel:  83 (127) arr at delivery centre
# [ 3] 14:15:06.7 Parcel:  84 (127) arr at delivery centre
# [ 3] 14:21:16.2 Parcel:  85 (130) arr at delivery centre
# [ 3] 14:53:08.4 Parcel:  86 (131) arr at delivery centre
# [ 3] 15:29:17.5 Parcel:  87 (138) arr at delivery centre
# [ 3] 16:12:19.5 Parcel:  88 (148) arr at delivery centre
# [ 3] 16:29:20.2 Parcel:  89 (149) arr at delivery centre
# [ 3] 18:00:00.0 Driver arrives for work
# [ 3] 18:00:00.0 Parcel:  79 (112) out for delivery
# [ 3] 18:00:00.0 Parcel:  80 (114) out for delivery
# [ 3] 18:00:00.0 Parcel:  59 ( 95) out for delivery
# [ 3] 18:00:00.0 Parcel:  72 ( 43) out for delivery
# [ 3] 18:00:00.0 Parcel:  68 (  0) out for delivery
# [ 3] 18:00:00.0 Parcel:  69 ( 23) out for delivery
# [ 3] 18:00:00.0 Parcel:  71 ( 42) out for delivery
# [ 3] 18:00:00.0 Parcel:  70 ( 36) out for delivery
# [ 3] 18:00:00.0 Parcel:  73 ( 48) out for delivery
# [ 3] 18:00:00.0 Parcel:  74 ( 62) out for delivery
# [ 3] 18:00:00.0 Parcel:  75 ( 82) out for delivery
# [ 3] 18:00:00.0 Parcel:  76 ( 93) out for delivery
# [ 3] 18:00:00.0 Parcel:  77 ( 98) out for delivery
# [ 3] 18:00:00.0 Parcel:  78 ( 98) out for delivery
# [ 3] 18:00:00.0 Parcel:  81 (121) out for delivery
# [ 3] 18:00:00.0 Parcel:  85 (130) out for delivery
# [ 3] 18:00:00.0 Parcel:  89 (149) out for delivery
# [ 3] 18:00:00.0 Parcel:  67 (148) out for delivery
# [ 3] 18:00:00.0 Parcel:  88 (148) out for delivery
# [ 3] 18:00:00.0 Parcel:  65 (141) out for delivery
# [ 3] 18:16:40.0 Driver leaves for delivery of 20 parcels
# [ 3] 18:16:40.0 Driver drives to Customer: 112 (5489, 830)
# [ 3] 18:25:28.4 Driver arrived at Customer: 112 (5489, 830)
# [ 3] 18:25:40.3 Customer: 112 (5489, 830) answers door
# [ 3] 18:25:40.3 Customer: 112 (5489, 830) accepts Parcel:  79 (112)
# [ 3] 18:25:55.6 Customer: 112 (5489, 830) signs off
# [ 3] 18:26:14.1 Driver drives to Customer: 114 (5680, 2188)
# [ 3] 18:34:30.9 Driver arrived at Customer: 114 (5680, 2188)
# [ 3] 18:35:05.9 Customer: 114 (5680, 2188) answers door
# [ 3] 18:35:05.9 Customer: 114 (5680, 2188) accepts Parcel:  80 (114)
# [ 3] 18:35:18.6 Customer: 114 (5680, 2188) signs off
# [ 3] 18:35:35.0 Driver drives to Customer: 95 (4747, 4560)
# [ 3] 18:48:48.2 Driver arrived at Customer: 95 (4747, 4560)
# [ 3] 18:48:51.0 Customer: 95 (4747, 4560) answers door
# [ 3] 18:48:51.0 Customer: 95 (4747, 4560) accepts Parcel:  59 ( 95)
# [ 3] 18:48:51.8 Customer: 95 (4747, 4560) signs off
# [ 3] 18:49:12.2 Driver drives to Customer: 43 (2659, 4000)
# [ 3] 19:02:57.5 Driver arrived at Customer: 43 (2659, 4000)
# [ 3] 19:02:59.1 Customer: 43 (2659, 4000) answers door
# [ 3] 19:02:59.1 Customer: 43 (2659, 4000) accepts Parcel:  72 ( 43)
# [ 3] 19:03:01.7 Customer: 43 (2659, 4000) signs off
# [ 3] 19:03:02.1 Driver drives to Customer:  0 (640, 2564)
# [ 3] 19:15:32.3 Driver arrived at Customer:  0 (640, 2564)
# [ 3] 19:15:32.9 Customer:  0 (640, 2564) answers door
# [ 3] 19:15:32.9 Customer:  0 (640, 2564) accepts Parcel:  68 (  0)
# [ 3] 19:15:51.5 Customer:  0 (640, 2564) signs off
# [ 3] 19:15:55.5 Driver drives to Customer: 23 (1995, 6240)
# [ 3] 19:34:44.0 Driver arrived at Customer: 23 (1995, 6240)
# [ 3] 19:34:51.0 Customer: 23 (1995, 6240) answers door
# [ 3] 19:34:51.0 Customer: 23 (1995, 6240) accepts Parcel:  69 ( 23)
# [ 3] 19:34:52.6 Customer: 23 (1995, 6240) signs off
# [ 3] 19:35:03.3 Driver drives to Customer: 42 (2611, 6240)
# [ 3] 19:37:31.1 Driver arrived at Customer: 42 (2611, 6240)
# [ 3] 19:39:49.6 Customer: 42 (2611, 6240) answers door
# [ 3] 19:39:49.6 Customer: 42 (2611, 6240) accepts Parcel:  71 ( 42)
# [ 3] 19:39:56.6 Customer: 42 (2611, 6240) signs off
# [ 3] 19:40:19.8 Driver drives to Customer: 36 (2320, 7047)
# [ 3] 19:44:43.3 Driver arrived at Customer: 36 (2320, 7047)
# [ 3] 19:45:11.2 Customer: 36 (2320, 7047) answers door
# [ 3] 19:45:11.2 Customer: 36 (2320, 7047) accepts Parcel:  70 ( 36)
# [ 3] 19:45:19.7 Customer: 36 (2320, 7047) signs off
# [ 3] 19:45:31.1 Driver drives to Customer: 48 (2732, 7360)
# [ 3] 19:48:25.1 Driver arrived at Customer: 48 (2732, 7360)
# [ 3] 19:49:30.5 Customer: 48 (2732, 7360) answers door
# [ 3] 19:49:30.5 Customer: 48 (2732, 7360) accepts Parcel:  73 ( 48)
# [ 3] 19:49:44.7 Customer: 48 (2732, 7360) signs off
# [ 3] 19:50:31.3 Driver drives to Customer: 62 (2880, 6970)
# [ 3] 19:52:40.4 Driver arrived at Customer: 62 (2880, 6970)
# [ 3] 19:53:35.4 Customer: 62 (2880, 6970) answers door
# [ 3] 19:53:35.4 Customer: 62 (2880, 6970) accepts Parcel:  74 ( 62)
# [ 3] 19:53:59.0 Customer: 62 (2880, 6970) signs off
# [ 3] 19:54:01.3 Driver drives to Customer: 82 (4000, 6598)
# [ 3] 20:03:06.6 Driver arrived at Customer: 82 (4000, 6598)
# [ 3] 20:03:37.2 Customer: 82 (4000, 6598) answers door
# [ 3] 20:03:37.2 Customer: 82 (4000, 6598) accepts Parcel:  75 ( 82)
# [ 3] 20:03:46.4 Customer: 82 (4000, 6598) signs off
# [ 3] 20:04:03.8 Driver drives to Customer: 93 (4391, 7360)
# [ 3] 20:08:40.5 Driver arrived at Customer: 93 (4391, 7360)
# [ 3] 20:09:06.9 Customer: 93 (4391, 7360) answers door
# [ 3] 20:09:06.9 Customer: 93 (4391, 7360) accepts Parcel:  76 ( 93)
# [ 3] 20:09:22.5 Customer: 93 (4391, 7360) signs off
# [ 3] 20:09:27.5 Driver drives to Customer: 98 (4819, 7360)
# [ 3] 20:11:10.2 Driver arrived at Customer: 98 (4819, 7360)
# [ 3] 20:11:45.5 Customer: 98 (4819, 7360) answers door
# [ 3] 20:11:45.5 Customer: 98 (4819, 7360) accepts Parcel:  77 ( 98)
# [ 3] 20:12:04.5 Customer: 98 (4819, 7360) accepts Parcel:  78 ( 98)
# [ 3] 20:12:20.5 Customer: 98 (4819, 7360) signs off
# [ 3] 20:12:31.2 Driver drives to Customer: 121 (6047, 6607)
# [ 3] 20:20:13.0 Driver arrived at Customer: 121 (6047, 6607)
# [ 3] 20:20:13.0 Customer: 121 (6047, 6607) answers door
# [ 3] 20:20:13.0 Customer: 121 (6047, 6607) accepts Parcel:  81 (121)
# [ 3] 20:20:15.0 Customer: 121 (6047, 6607) signs off
# [ 3] 20:20:22.1 Driver drives to Customer: 130 (6521, 6518)
# [ 3] 20:23:02.9 Driver arrived at Customer: 130 (6521, 6518)
# [ 3] 20:23:14.6 Customer: 130 (6521, 6518) answers door
# [ 3] 20:23:14.6 Customer: 130 (6521, 6518) accepts Parcel:  85 (130)
# [ 3] 20:23:15.3 Customer: 130 (6521, 6518) signs off
# [ 3] 20:23:35.0 Driver drives to Customer: 149 (7360, 5367)
# [ 3] 20:29:34.2 Driver arrived at Customer: 149 (7360, 5367)
# [ 3] 20:31:28.8 Customer: 149 (7360, 5367) answers door
# [ 3] 20:31:28.8 Customer: 149 (7360, 5367) accepts Parcel:  89 (149)
# [ 3] 20:31:32.4 Customer: 149 (7360, 5367) signs off
# [ 3] 20:31:37.6 Driver drives to Customer: 148 (7360, 3794)
# [ 3] 20:37:55.2 Driver arrived at Customer: 148 (7360, 3794)
# [ 3] 20:39:01.6 Customer: 148 (7360, 3794) answers door
# [ 3] 20:39:01.6 Customer: 148 (7360, 3794) accepts Parcel:  67 (148)
# [ 3] 20:39:02.2 Customer: 148 (7360, 3794) accepts Parcel:  88 (148)
# [ 3] 20:39:12.5 Customer: 148 (7360, 3794) signs off
# [ 3] 20:39:13.9 Driver drives to Customer: 141 (7104, 3440)
# [ 3] 20:41:40.3 Driver arrived at Customer: 141 (7104, 3440)
# [ 3] 20:41:53.8 Customer: 141 (7104, 3440) answers door
# [ 3] 20:41:53.8 Customer: 141 (7104, 3440) accepts Parcel:  65 (141)
# [ 3] 20:42:11.5 Customer: 141 (7104, 3440) signs off
# [ 3] 20:42:12.1 Driver returns to delivery centre
# [ 3] 20:53:06.6 Driver arrived at delivery centre
# [ 3] 21:03:06.6 5 left over for next day
# [ 3] 21:03:06.6 Driver goes home
# [ 4] 08:35:52.9 Parcel:  90 (  2) arr at delivery centre
# [ 4] 08:46:17.0 Parcel:  91 (  2) arr at delivery centre
# [ 4] 08:53:28.2 Parcel:  92 (  3) arr at delivery centre
# [ 4] 09:06:25.5 Parcel:  93 ( 10) arr at delivery centre
# [ 4] 10:13:28.9 Parcel:  94 ( 11) arr at delivery centre
# [ 4] 10:43:20.4 Parcel:  95 ( 13) arr at delivery centre
# [ 4] 11:02:15.6 Parcel:  96 ( 14) arr at delivery centre
# [ 4] 11:03:17.5 Parcel:  97 ( 19) arr at delivery centre
# [ 4] 11:14:40.6 Parcel:  98 ( 19) arr at delivery centre
# [ 4] 11:22:40.4 Parcel:  99 ( 24) arr at delivery centre
# [ 4] 11:34:36.5 Parcel: 100 ( 30) arr at delivery centre
# [ 4] 11:56:59.2 Parcel: 101 ( 32) arr at delivery centre
# [ 4] 12:00:19.7 Parcel: 102 ( 36) arr at delivery centre
# [ 4] 12:16:06.4 Parcel: 103 ( 38) arr at delivery centre
# [ 4] 12:17:36.1 Parcel: 104 ( 40) arr at delivery centre
# [ 4] 12:20:35.4 Parcel: 105 ( 41) arr at delivery centre
# [ 4] 12:39:35.0 Parcel: 106 ( 42) arr at delivery centre
# [ 4] 12:44:26.0 Parcel: 107 ( 43) arr at delivery centre
# [ 4] 13:04:44.5 Parcel: 108 ( 50) arr at delivery centre
# [ 4] 13:06:00.8 Parcel: 109 ( 51) arr at delivery centre
# [ 4] 13:07:54.7 Parcel: 110 ( 58) arr at delivery centre
# [ 4] 13:22:16.0 Parcel: 111 ( 67) arr at delivery centre
# [ 4] 13:22:49.3 Parcel: 112 ( 72) arr at delivery centre
# [ 4] 13:33:03.5 Parcel: 113 ( 72) arr at delivery centre
# [ 4] 14:01:57.3 Parcel: 114 ( 77) arr at delivery centre
# [ 4] 14:11:07.4 Parcel: 115 ( 80) arr at delivery centre
# [ 4] 14:24:49.1 Parcel: 116 ( 86) arr at delivery centre
# [ 4] 14:25:08.6 Parcel: 117 ( 94) arr at delivery centre
# [ 4] 14:37:14.3 Parcel: 118 ( 95) arr at delivery centre
# [ 4] 14:48:25.5 Parcel: 119 (104) arr at delivery centre
# [ 4] 14:58:43.2 Parcel: 120 (107) arr at delivery centre
# [ 4] 15:04:40.5 Parcel: 121 (112) arr at delivery centre
# [ 4] 15:10:13.3 Parcel: 122 (115) arr at delivery centre
# [ 4] 15:57:28.8 Parcel: 123 (125) arr at delivery centre
# [ 4] 15:57:55.5 Parcel: 124 (128) arr at delivery centre
# [ 4] 18:00:00.0 Driver arrives for work
# [ 4] 18:00:00.0 Parcel: 117 ( 94) out for delivery
# [ 4] 18:00:00.0 Parcel: 112 ( 72) out for delivery
# [ 4] 18:00:00.0 Parcel: 113 ( 72) out for delivery
# [ 4] 18:00:00.0 Parcel: 109 ( 51) out for delivery
# [ 4] 18:00:00.0 Parcel: 103 ( 38) out for delivery
# [ 4] 18:00:00.0 Parcel: 108 ( 50) out for delivery
# [ 4] 18:00:00.0 Parcel: 111 ( 67) out for delivery
# [ 4] 18:00:00.0 Parcel:  99 ( 24) out for delivery
# [ 4] 18:00:00.0 Parcel: 100 ( 30) out for delivery
# [ 4] 18:00:00.0 Parcel: 105 ( 41) out for delivery
# [ 4] 18:00:00.0 Parcel: 110 ( 58) out for delivery
# [ 4] 18:00:00.0 Parcel: 107 ( 43) out for delivery
# [ 4] 18:00:00.0 Parcel: 101 ( 32) out for delivery
# [ 4] 18:00:00.0 Parcel:  95 ( 13) out for delivery
# [ 4] 18:00:00.0 Parcel:  93 ( 10) out for delivery
# [ 4] 18:00:00.0 Parcel:  90 (  2) out for delivery
# [ 4] 18:00:00.0 Parcel:  91 (  2) out for delivery
# [ 4] 18:00:00.0 Parcel:  92 (  3) out for delivery
# [ 4] 18:00:00.0 Parcel:  94 ( 11) out for delivery
# [ 4] 18:00:00.0 Parcel:  96 ( 14) out for delivery
# [ 4] 18:00:00.0 Parcel:  97 ( 19) out for delivery
# [ 4] 18:00:00.0 Parcel:  98 ( 19) out for delivery
# [ 4] 18:00:00.0 Parcel: 106 ( 42) out for delivery
# [ 4] 18:00:00.0 Parcel: 102 ( 36) out for delivery
# [ 4] 18:00:00.0 Parcel: 104 ( 40) out for delivery
# [ 4] 18:00:00.0 Parcel: 114 ( 77) out for delivery
# [ 4] 18:00:00.0 Parcel: 119 (104) out for delivery
# [ 4] 18:00:00.0 Parcel: 120 (107) out for delivery
# [ 4] 18:00:00.0 Parcel: 123 (125) out for delivery
# [ 4] 18:00:00.0 Parcel:  83 (127) out for delivery
# [ 4] 18:00:00.0 Parcel:  84 (127) out for delivery
# [ 4] 18:00:00.0 Parcel:  87 (138) out for delivery
# [ 4] 18:00:00.0 Parcel:  86 (131) out for delivery
# [ 4] 18:00:00.0 Parcel: 124 (128) out for delivery
# [ 4] 18:00:00.0 Parcel:  82 (123) out for delivery
# [ 4] 18:00:00.0 Parcel: 122 (115) out for delivery
# [ 4] 18:30:00.0 Driver leaves for delivery of 36 parcels
# [ 4] 18:30:00.0 Driver drives to Customer: 94 (4739, 1760)
# [ 4] 18:36:00.2 Driver arrived at Customer: 94 (4739, 1760)
# [ 4] 18:36:01.7 Customer: 94 (4739, 1760) answers door
# [ 4] 18:36:01.7 Customer: 94 (4739, 1760) accepts Parcel: 117 ( 94)
# [ 4] 18:36:07.1 Customer: 94 (4739, 1760) signs off
# [ 4] 18:36:13.8 Driver drives to Customer: 72 (3632, 2127)
# [ 4] 18:41:15.8 Driver arrived at Customer: 72 (3632, 2127)
# [ 4] 18:42:35.4 Customer: 72 (3632, 2127) answers door
# [ 4] 18:42:35.4 Customer: 72 (3632, 2127) accepts Parcel: 112 ( 72)
# [ 4] 18:42:48.0 Customer: 72 (3632, 2127) accepts Parcel: 113 ( 72)
# [ 4] 18:42:59.2 Customer: 72 (3632, 2127) signs off
# [ 4] 18:43:00.8 Driver drives to Customer: 51 (2880, 1424)
# [ 4] 18:49:55.5 Driver arrived at Customer: 51 (2880, 1424)
# [ 4] 18:52:48.4 Customer: 51 (2880, 1424) answers door
# [ 4] 18:52:48.4 Customer: 51 (2880, 1424) accepts Parcel: 109 ( 51)
# [ 4] 19:31:29.5 Customer: 43 (2659, 4000) signs off
# [ 4] 19:31:53.8 Driver drives to Customer: 32 (2320, 4217)
# [ 4] 19:34:07.3 Driver arrived at Customer: 32 (2320, 4217)
# [ 4] 19:35:11.5 Customer: 32 (2320, 4217) answers door
# [ 4] 19:35:11.5 Customer: 32 (2320, 4217) accepts Parcel: 101 ( 32)
# [ 4] 19:35:36.4 Customer: 32 (2320, 4217) signs off
# [ 4] 19:35:57.0 Driver drives to Customer: 13 (1466, 4000)
# [ 4] 19:40:14.0 Driver arrived at Customer: 13 (1466, 4000)
# [ 4] 19:40:59.7 Customer: 13 (1466, 4000) answers door
# [ 4] 19:40:59.7 Customer: 13 (1466, 4000) accepts Parcel:  95 ( 13)
# [ 4] 19:41:16.3 Customer: 13 (1466, 4000) signs off
# [ 4] 19:41:23.7 Driver drives to Customer: 10 (1200, 4173)
# [ 4] 19:43:09.0 Driver arrived at Customer: 10 (1200, 4173)
# [ 4] 19:44:10.6 Customer: 10 (1200, 4173) answers door
# [ 4] 19:44:10.6 Customer: 10 (1200, 4173) accepts Parcel:  93 ( 10)
# [ 4] 19:44:12.7 Customer: 10 (1200, 4173) signs off
# [ 4] 19:44:27.9 Driver drives to Customer:  2 (640, 4216)
# [ 4] 19:48:15.7 Driver arrived at Customer:  2 (640, 4216)
# [ 4] 19:48:39.2 Customer:  2 (640, 4216) answers door
# [ 4] 19:48:39.2 Customer:  2 (640, 4216) accepts Parcel:  90 (  2)
# [ 4] 19:48:53.3 Customer:  2 (640, 4216) accepts Parcel:  91 (  2)
# [ 4] 19:48:59.4 Customer:  2 (640, 4216) signs off
# [ 4] 19:49:15.0 Driver drives to Customer:  3 (640, 4336)
# [ 4] 19:49:43.8 Driver arrived at Customer:  3 (640, 4336)
# [ 4] 19:49:46.9 Customer:  3 (640, 4336) answers door
# [ 4] 19:49:46.9 Customer:  3 (640, 4336) accepts Parcel:  92 (  3)
# [ 4] 19:49:47.4 Customer:  3 (640, 4336) signs off
# [ 4] 19:50:14.6 Driver drives to Customer: 11 (1200, 4797)
# [ 4] 19:54:19.7 Driver arrived at Customer: 11 (1200, 4797)
# [ 4] 19:54:46.3 Customer: 11 (1200, 4797) answers door
# [ 4] 19:54:46.3 Customer: 11 (1200, 4797) accepts Parcel:  94 ( 11)
# [ 4] 19:55:09.4 Customer: 11 (1200, 4797) signs off
# [ 4] 19:55:38.4 Driver drives to Customer: 14 (1490, 5120)
# [ 4] 19:58:05.5 Driver arrived at Customer: 14 (1490, 5120)
# [ 4] 19:58:49.4 Customer: 14 (1490, 5120) answers door
# [ 4] 19:58:49.4 Customer: 14 (1490, 5120) accepts Parcel:  96 ( 14)
# [ 4] 19:58:57.9 Customer: 14 (1490, 5120) signs off
# [ 4] 19:59:00.4 Driver drives to Customer: 19 (1760, 5886)
# [ 4] 20:03:09.0 Driver arrived at Customer: 19 (1760, 5886)
# [ 4] 20:03:12.9 Customer: 19 (1760, 5886) answers door
# [ 5] 20:53:15.0 Customer: 139 (7000, 6038) accepts Parcel: 150 (139)
# [ 5] 20:53:15.4 Customer: 139 (7000, 6038) signs off
# [ 5] 20:53:18.4 Driver drives to Customer: 149 (7360, 5367)
# [ 5] 20:56:35.2 Driver arrived at Customer: 149 (7360, 5367)
# [ 5] 20:57:05.1 Customer: 149 (7360, 5367) answers door
# [ 5] 20:57:05.1 Customer: 149 (7360, 5367) accepts Parcel: 151 (149)
# [ 5] 20:57:13.8 Customer: 149 (7360, 5367) signs off
# [ 5] 20:57:18.8 Driver returns to delivery centre
# [ 5] 21:02:46.9 Driver arrived at delivery centre
# [ 5] 21:12:46.9 0 left over for next day
# [ 5] 21:12:46.9 Driver goes home
# [ 6] 08:01:05.3 Parcel: 152 (  2) arr at delivery centre
# [ 6] 08:21:40.8 Parcel: 153 (  3) arr at delivery centre
# [ 6] 08:55:46.5 Parcel: 154 ( 11) arr at delivery centre
# [ 6] 09:03:25.5 Parcel: 155 ( 11) arr at delivery centre
# [ 6] 09:08:41.7 Parcel: 156 ( 24) arr at delivery centre
# [ 6] 09:25:16.9 Parcel: 157 ( 27) arr at delivery centre
# [ 6] 09:35:56.7 Parcel: 158 ( 32) arr at delivery centre
# [ 6] 09:39:27.2 Parcel: 159 ( 35) arr at delivery centre
# [ 6] 09:51:06.2 Parcel: 160 ( 43) arr at delivery centre
# [ 6] 10:00:44.1 Parcel: 161 ( 44) arr at delivery centre
# [ 6] 10:16:06.5 Parcel: 162 ( 51) arr at delivery centre
# [ 6] 10:29:05.0 Parcel: 163 ( 53) arr at delivery centre
# [ 6] 10:35:54.0 Parcel: 164 ( 67) arr at delivery centre
# [ 6] 10:43:58.0 Parcel: 165 ( 93) arr at delivery centre
# [ 6] 11:17:10.0 Parcel: 166 (104) arr at delivery centre
# [ 6] 11:22:26.6 Parcel: 167 (111) arr at delivery centre
# [ 6] 11:37:27.6 Parcel: 168 (111) arr at delivery centre
# [ 6] 11:37:41.3 Parcel: 169 (118) arr at delivery centre
# [ 6] 12:02:23.9 Parcel: 170 (125) arr at delivery centre
# [ 6] 12:09:52.4 Parcel: 171 (125) arr at delivery centre
# [ 6] 12:10:43.6 Parcel: 172 (129) arr at delivery centre
# [ 6] 12:16:44.9 Parcel: 173 (138) arr at delivery centre
# [ 6] 12:21:45.8 Parcel: 174 (148) arr at delivery centre
# [ 6] 18:00:00.0 Driver arrives for work
# [ 6] 18:00:00.0 Parcel: 174 (148) out for delivery
# [ 6] 18:00:00.0 Parcel: 173 (138) out for delivery
# [ 6] 18:00:00.0 Parcel: 172 (129) out for delivery
# [ 6] 18:00:00.0 Parcel: 167 (111) out for delivery
# [ 6] 18:00:00.0 Parcel: 168 (111) out for delivery
# [ 6] 18:00:00.0 Parcel: 161 ( 44) out for delivery
# [ 6] 18:00:00.0 Parcel: 163 ( 53) out for delivery
# [ 6] 18:00:00.0 Parcel: 162 ( 51) out for delivery
# [ 6] 18:00:00.0 Parcel: 164 ( 67) out for delivery
# [ 6] 18:00:00.0 Parcel: 157 ( 27) out for delivery
# [ 6] 18:00:00.0 Parcel: 156 ( 24) out for delivery
# [ 6] 18:00:00.0 Parcel: 158 ( 32) out for delivery
# [ 6] 18:00:00.0 Parcel: 160 ( 43) out for delivery
# [ 6] 18:00:00.0 Parcel: 152 (  2) out for delivery
# [ 6] 18:00:00.0 Parcel: 153 (  3) out for delivery
# [ 6] 18:00:00.0 Parcel: 154 ( 11) out for delivery
# [ 6] 18:00:00.0 Parcel: 155 ( 11) out for delivery
# [ 6] 18:00:00.0 Parcel: 159 ( 35) out for delivery
# [ 6] 18:00:00.0 Parcel: 165 ( 93) out for delivery
# [ 6] 18:00:00.0 Parcel: 166 (104) out for delivery
# [ 6] 18:00:00.0 Parcel: 169 (118) out for delivery
# [ 6] 18:00:00.0 Parcel: 170 (125) out for delivery
# [ 6] 18:00:00.0 Parcel: 171 (125) out for delivery
# [ 6] 18:19:10.0 Driver leaves for delivery of 23 parcels
# [ 6] 18:19:10.0 Driver drives to Customer: 148 (7360, 3794)
# [ 6] 18:19:59.4 Driver arrived at Customer: 148 (7360, 3794)
# [ 6] 18:20:03.7 Customer: 148 (7360, 3794) answers door
# [ 6] 18:20:03.7 Customer: 148 (7360, 3794) accepts Parcel: 174 (148)
# [ 6] 18:20:06.6 Customer: 148 (7360, 3794) signs off
# [ 6] 18:20:09.9 Driver drives to Customer: 138 (6969, 2880)
# [ 6] 18:25:23.1 Driver arrived at Customer: 138 (6969, 2880)
# [ 6] 18:26:19.4 Customer: 138 (6969, 2880) answers door
# [ 6] 18:26:19.4 Customer: 138 (6969, 2880) accepts Parcel: 173 (138)
# [ 6] 18:26:43.4 Customer: 138 (6969, 2880) signs off
# [ 6] 18:26:52.4 Driver drives to Customer: 129 (6510, 2880)
# [ 6] 18:28:42.6 Driver arrived at Customer: 129 (6510, 2880)
# [ 6] 18:28:44.0 Customer: 129 (6510, 2880) answers door
# [ 6] 18:28:44.0 Customer: 129 (6510, 2880) accepts Parcel: 172 (129)
# [ 6] 18:28:59.7 Customer: 129 (6510, 2880) signs off
# [ 6] 18:29:03.4 Driver drives to Customer: 111 (5445, 3440)
# [ 6] 18:35:33.4 Driver arrived at Customer: 111 (5445, 3440)
# [ 6] 18:35:50.0 Customer: 111 (5445, 3440) answers door
# [ 6] 18:35:50.0 Customer: 111 (5445, 3440) accepts Parcel: 167 (111)
# [ 6] 18:35:57.6 Customer: 111 (5445, 3440) accepts Parcel: 168 (111)
# [ 6] 18:36:00.4 Customer: 111 (5445, 3440) signs off
# [ 6] 18:36:25.7 Driver drives to Customer: 44 (2684, 2880)
# [ 6] 18:49:42.7 Driver arrived at Customer: 44 (2684, 2880)
# [ 6] 18:49:49.9 Customer: 44 (2684, 2880) answers door
# [ 6] 18:49:49.9 Customer: 44 (2684, 2880) accepts Parcel: 161 ( 44)
# [ 6] 18:49:55.2 Customer: 44 (2684, 2880) signs off
# [ 6] 18:49:58.6 Driver drives to Customer: 53 (2880, 2004)
# [ 6] 18:54:15.9 Driver arrived at Customer: 53 (2880, 2004)
# [ 6] 18:54:45.3 Customer: 53 (2880, 2004) answers door
# [ 6] 18:54:45.3 Customer: 53 (2880, 2004) accepts Parcel: 163 ( 53)
# [ 6] 18:54:53.8 Customer: 53 (2880, 2004) signs off
# [ 6] 18:55:03.7 Driver drives to Customer: 51 (2880, 1424)
# [ 6] 18:57:22.9 Driver arrived at Customer: 51 (2880, 1424)
# [ 6] 18:57:53.2 Customer: 51 (2880, 1424) answers door
# [ 6] 18:57:53.2 Customer: 51 (2880, 1424) accepts Parcel: 162 ( 51)
# [ 6] 18:57:58.5 Customer: 51 (2880, 1424) signs off
# [ 6] 18:58:08.5 Driver drives to Customer: 67 (3255, 640)
# [ 6] 19:02:46.7 Driver arrived at Customer: 67 (3255, 640)
# [ 6] 19:03:07.4 Customer: 67 (3255, 640) answers door
# [ 6] 19:03:07.4 Customer: 67 (3255, 640) accepts Parcel: 164 ( 67)
# [ 6] 19:03:22.4 Customer: 67 (3255, 640) signs off
# [ 6] 19:03:38.0 Driver drives to Customer: 27 (2126, 2320)
# [ 6] 19:14:52.1 Driver arrived at Customer: 27 (2126, 2320)
# [ 6] 19:15:05.9 Customer: 27 (2126, 2320) answers door
# [ 6] 19:15:05.9 Customer: 27 (2126, 2320) accepts Parcel: 157 ( 27)
# [ 6] 19:15:10.6 Customer: 27 (2126, 2320) signs off
# [ 6] 19:15:20.5 Driver drives to Customer: 24 (2010, 2320)
# [ 6] 19:15:48.3 Driver arrived at Customer: 24 (2010, 2320)
# [ 6] 19:15:55.2 Customer: 24 (2010, 2320) answers door
# [ 6] 19:15:55.2 Customer: 24 (2010, 2320) accepts Parcel: 156 ( 24)
# [ 6] 19:16:07.1 Customer: 24 (2010, 2320) signs off
# [ 6] 19:16:11.9 Driver drives to Customer: 32 (2320, 4217)
# [ 6] 19:25:01.6 Driver arrived at Customer: 32 (2320, 4217)
# [ 6] 19:25:37.4 Customer: 32 (2320, 4217) answers door
# [ 6] 19:25:37.4 Customer: 32 (2320, 4217) accepts Parcel: 158 ( 32)
# [ 6] 19:25:38.9 Customer: 32 (2320, 4217) signs off
# [ 6] 19:25:49.9 Driver drives to Customer: 43 (2659, 4000)
# [ 6] 19:28:03.3 Driver arrived at Customer: 43 (2659, 4000)
# [ 6] 19:28:20.8 Customer: 43 (2659, 4000) answers door
# [ 6] 19:28:20.8 Customer: 43 (2659, 4000) accepts Parcel: 160 ( 43)
# [ 6] 19:28:27.2 Customer: 43 (2659, 4000) signs off
# [ 6] 19:28:32.6 Driver drives to Customer:  2 (640, 4216)
# [ 6] 19:37:29.0 Driver arrived at Customer:  2 (640, 4216)
# [ 6] 19:37:54.9 Customer:  2 (640, 4216) answers door
# [ 6] 19:37:54.9 Customer:  2 (640, 4216) accepts Parcel: 152 (  2)
# [ 6] 19:38:06.8 Customer:  2 (640, 4216) signs off
# [ 6] 19:38:10.6 Driver drives to Customer:  3 (640, 4336)
# [ 6] 19:38:39.4 Driver arrived at Customer:  3 (640, 4336)
# [ 6] 19:39:21.6 Customer:  3 (640, 4336) answers door
# [ 6] 19:39:21.6 Customer:  3 (640, 4336) accepts Parcel: 153 (  3)
# [ 6] 19:39:22.2 Customer:  3 (640, 4336) signs off
# [ 6] 19:39:25.8 Driver drives to Customer: 11 (1200, 4797)
# [ 6] 19:43:30.9 Driver arrived at Customer: 11 (1200, 4797)
# [ 6] 19:44:25.5 Customer: 11 (1200, 4797) answers door
# [ 6] 19:44:25.5 Customer: 11 (1200, 4797) accepts Parcel: 154 ( 11)
# [ 6] 19:44:26.1 Customer: 11 (1200, 4797) accepts Parcel: 155 ( 11)
# [ 6] 19:44:35.8 Customer: 11 (1200, 4797) signs off
# [ 6] 19:44:36.0 Driver drives to Customer: 35 (2320, 6492)
# [ 6] 19:55:51.6 Driver arrived at Customer: 35 (2320, 6492)
# [ 6] 19:56:17.2 Customer: 35 (2320, 6492) answers door
# [ 6] 19:56:17.2 Customer: 35 (2320, 6492) accepts Parcel: 159 ( 35)
# [ 6] 19:56:39.1 Customer: 35 (2320, 6492) signs off
# [ 6] 19:56:39.2 Driver drives to Customer: 93 (4391, 7360)
# [ 6] 20:08:24.6 Driver arrived at Customer: 93 (4391, 7360)
# [ 6] 20:08:54.5 Customer: 93 (4391, 7360) answers door
# [ 6] 20:08:54.5 Customer: 93 (4391, 7360) accepts Parcel: 165 ( 93)
# [ 6] 20:08:55.2 Customer: 93 (4391, 7360) signs off
# [ 6] 20:09:15.4 Driver drives to Customer: 104 (5120, 7217)
# [ 6] 20:12:44.6 Driver arrived at Customer: 104 (5120, 7217)
# [ 6] 20:13:31.0 Customer: 104 (5120, 7217) answers door
# [ 6] 20:13:31.0 Customer: 104 (5120, 7217) accepts Parcel: 166 (104)
# [ 6] 20:13:44.6 Customer: 104 (5120, 7217) signs off
# [ 6] 20:13:55.6 Driver drives to Customer: 118 (5780, 5680)
# [ 6] 20:21:23.9 Driver arrived at Customer: 118 (5780, 5680)
# [ 6] 20:21:24.2 Customer: 118 (5780, 5680) answers door
# [ 6] 20:21:24.2 Customer: 118 (5780, 5680) accepts Parcel: 169 (118)
# [ 6] 20:21:24.6 Customer: 118 (5780, 5680) signs off
# [ 6] 20:21:34.3 Driver drives to Customer: 125 (6240, 4934)
# [ 6] 20:26:23.8 Driver arrived at Customer: 125 (6240, 4934)
# [ 6] 20:31:46.3 Customer: 125 (6240, 4934) answers door
# [ 6] 20:31:46.3 Customer: 125 (6240, 4934) accepts Parcel: 170 (125)
# [ 6] 20:32:06.9 Customer: 125 (6240, 4934) accepts Parcel: 171 (125)
# [ 6] 20:32:19.0 Customer: 125 (6240, 4934) signs off
# [ 6] 20:32:32.0 Driver returns to delivery centre
# [ 6] 20:40:44.9 Driver arrived at delivery centre
# [ 6] 20:50:44.9 0 left over for next day
# [ 6] 20:50:44.9 Driver goes home
# Delivery Centre Inventory: 0 parcels

# %%
random.seed(0)
W = generateWarehouseLocations(M, seed=9340)
with open(f'warehouseData.pickle', 'wb') as f:
    pickle.dump(W, f)
